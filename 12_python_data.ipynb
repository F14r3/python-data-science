# %% [markdown]
# # Data science in Python
#
# - Course GitHub repo: https://github.com/pycam/python-data-science
# - Python website: https://www.python.org/
#
# ## Session 1.2: Using existing python modules to explore data in files
#
# - [Importing module `statistics`](#Importing-module-statistics)
#   - [Exercise 1.2.1](#Exercise-1.2.1)
# - [Python file and directory manipulations](#Python-file-and-directory-manipulations)
#   - [Exercise 1.2.2](#Exercise-1.2.2)
# - [Using the `csv` module](#Using-the-csv-module)
#   - [Exercise 3.2](#Exercise-3.2)

# %% [markdown]
# ## Mind map
#
# <img src="img/mind_maps/mind_maps.002.jpeg">

# %% [markdown]
# ## Importing module `statistics`

# %% [markdown]
# Like other laguages, Python has the ability to import external modules (or libraries) into the current program. These modules may be part of the standard library that is automatically included with the Python installation, they may be extra libraries which you install separately or they may be other Python programs you have written yourself. Whatever the source of the module, they are imported into a program via an **`import`** command.
#
# For example, if we wish to access the `mean()` and `median()` functions in Python, we can use the **`import`** keyword to get [the module named `statistics`](https://docs.python.org/3/library/statistics.html) and access its contents with the dot notation:

# %%
import statistics
statistics.mean([1, 2, 3, 4, 4])

# %% [markdown]
# Also we can use the `as` keyword to give the module a different name in our code, which can be useful for brevity and avoiding name conflicts:

# %%
import statistics as stats
stats.mean([1, 2, 3, 4, 4])

# %% [markdown]
# Alternatively we can import the separate components using the `from … import` keyword combination:

# %%
from statistics import mean, median
mean([1, 2, 3, 4, 4])

# %% [markdown]
# We can import multiple components from a single module, either on one line like as seen above or on separate lines:

# %%
from statistics import mean
from statistics import median

# %% [markdown]
# ### Listing module contents
#
# Using the [function `dir()`](https://docs.python.org/3/library/functions.html?highlight=dir#dir) and passing the module name:

# %%
import statistics
dir(statistics)
# Out:
# ['Decimal',
#  'Fraction',
#  'StatisticsError',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_check_type',
#  '_counts',
#  '_decimal_to_ratio',
#  '_exact_ratio',
#  '_ss',
#  '_sum',
#  'collections',
#  'math',
#  'mean',
#  'median',
#  'median_grouped',
#  'median_high',
#  'median_low',
#  'mode',
#  'pstdev',
#  'pvariance',
#  'stdev',
#  'variance']

# %% [markdown]
# ### Getting help directly from Jupyter notebook

# %%
statistics?

# %%
help(statistics)

# %% [markdown]
# ## Exercise 1.2.1
#
# - Calculate the average GDP per capita per country in Europe in 1962, its median and standard deviation using `data/gapminder.csv` data; and compare these figures with those from Americas.

# %%
from statistics import mean, median, stdev
gdp_EUR_1962_list=[]
gdp_AME_1962_list=[]

with open("data/gapminder.csv") as f:
    header = next(f)  # comment out header 
    #print(header) 
    for line in f:

        data = line.strip().split(',')
        country = data[0]
        continent = data[1]
        year = int(data[2])
        gbpPercap = float(data[-1])
        
        if continent == "Europe" and year == 1962:
            gdp_EUR_1962_list.append(gbpPercap)
        if continent == "Americas" and year == 1962:
            gdp_AME_1962_list.append(gbpPercap)
            
    #print(gdp_EUR_1962_list)
print('GDP per capita per country in EUR in 1962')
print('mean', mean(gdp_EUR_1962_list), '  stddev', stdev(gdp_EUR_1962_list))
    
print('GDP per capita per country in AMR in 1962')
print('mean', mean(gdp_AME_1962_list), '  stddev', stdev(gdp_AME_1962_list))
# Out:
# GDP per capita per country in EUR in 1962
# mean 8365.4868143   stddev 4199.193906418378
# GDP per capita per country in AMR in 1962
# mean 4901.5418704   stddev 3421.740568771563

# %% [markdown]
# ## Python file and directory manipulations
#
# These two modules `os.path` and `os` implements some useful functions on pathnames, and for accessing the filesystem. To read or write files, we use `open()`.

# %% [markdown]
# ### [`os.path` — Common pathname manipulations](https://docs.python.org/3/library/os.path.html)
#
# - `join(*paths)` : joins the paths together into one long path
# - `exists(path)` : returns whether path exists
# - `isfile(path)` : returns whether path is a “regular” file (as opposed to a directory)
# - `isdir(path)` : returns whether path is a directory
# - `dirname(path)` : returns directory containing the path
# - `basename(path)` : returns the path minus the dirname(path) in front
# - `split(path)` : returns (dirname(path), basename(path))
#
# ### [`os` — Miscellaneous operating system interfaces](https://docs.python.org/3/library/os.html)
#
# - `listdir(path)` : returns a list of files/directories in the directory path

# %% [markdown]
# Building the path to your file from a list of directory and filename makes your script able to run on any platforms.

# %%
import os.path
data_filepath = os.path.join("data", "gapminder.csv")
# data/mydata.txt - Unix
# data\mydata.txt - Windows
print(data_filepath)
# Out:
# data/gapminder.csv

# %% [markdown]
# Checking if a file exists before opening it:

# %%
os.path.exists(data_filepath)

# %% [markdown]
# Checking if it is a file:

# %%
os.path.isfile(data_filepath)

# %% [markdown]
# or a directory:

# %%
os.path.isdir(data_filepath)

# %% [markdown]
# Extracting the directory of the file path:

# %%
data_dirname = os.path.dirname(data_filepath)
print(data_dirname)

# %% [markdown]
# Checking if it is a directory:

# %%
os.path.isdir(data_dirname)

# %% [markdown]
# Extracting the file name from the file path:

# %%
data_filename = os.path.basename(data_filepath)
print(data_filename)

# %% [markdown]
# Getting the directory and the file name from the file path using `os.path.split()` which returns two variables its directory and file name:

# %%
data_dirname, data_filename = os.path.split(data_filepath)
print(data_dirname, data_filename)

# %% [markdown]
# Listing the content of a directory using `os.listdir()` is equivalent to `ls` in the shell:

# %%
import os
print(os.listdir(data_dirname))

# %% [markdown]
# ## Exercise 1.2.2
#
# - List all `.txt` files from the `data` directory, print their file path only if it is a file.
# - Check that the file `genes.txt` exists in `data/`, open the tab separated file, and calculate the length of each genes.

# %%
import os

dName = 'data'

listContents = os.listdir(dName)
#print(listContents)

for content in listContents:
    filepath = os.path.join(dName, content)
    
    if os.path.isfile(filepath) and filepath.endswith('.txt'):
        print(filepath)
# Out:
# ['mydata.txt', 'gapminder_gdp_europe.csv', 'GRCm38.gff3', 'GRCh38.gff3', 'gapminder_gdp_africa.csv', 'AilMel.gff3', 'gapminder_gdp_americas.csv', 'genes.txt', 'genes_withstrand.txt', '.~lock.gapminder.csv#', 'gapminder.csv', 'gapminder_gdp_oceania.csv', 'glpa.fa', 'sample.fa', 'gapminder_gdp_asia.csv', 'GRCz11.gff3']
# data/mydata.txt
# data/genes.txt
# data/genes_withstrand.txt

# %%
import os

fName = os.path.join("data","genes.txt")

if os.path.exists(fName):
    print('file {} exists'.format(fName))
    with open(fName, 'r') as f:
        header = f.readline()
        print(header)
        for line in f:
            gene,chrom,startPos,endPos = line.strip().split('\t')
            genelength = int(endPos) - int(startPos) + 1
            print('{} gene has length = {}', format(gene, genelength))
# Out:
# file data/genes.txt exists
# gene	chrom	start	end
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-56-30d0fe28367d> in <module>()
#      11             gene,chrom,startPos,endPos = line.strip().split('\t')
#      12             genelength = int(endPos) - int(startPos) + 1
# ---> 13             print('{} gene has length = {}', format(gene, genelength))
#
# TypeError: must be str, not int

# %%
import os
data_filepath = os.path.join("data")
#print(os.listdir(data_filepath)[0])
for i in range(len(os.listdir(data_filepath))):
    if ".txt" in os.listdir(data_filepath)[i] and os.path.isfile(os.path.join("data",os.listdir(data_filepath)[1])):
        print(os.listdir(data_filepath)[i])


gene_filepath = os.path.join("data","genes.txt")
print(os.path.exists(gene_filepath))

with open(gene_filepath) as f:
    header = next(f)  # comment out header 
    #print(header) 
    for line in f:
        data = line.strip().split('\t')
        start = int(data[-2])
        end = int(data[-1])
        length = end - start
        print(data[0],'length:',length)
        #print(length)
        #data = line.strip().split(',')
        
# print(os.listdir(data_filepath)[1])
# print(os.path.isfile(os.path.join("data",os.listdir(data_filepath)[1])))
# Out:
# mydata.txt
# genes.txt
# genes_withstrand.txt
# True
# BRCA2 length: 84194
# TNFAIP3 length: 16098
# TCF7 length: 37154

# %% [markdown]
# ## Using the `csv` module
#
# The so-called CSV (Comma Separated Values) format is the most common import and export format for spreadsheets and databases. The `csv` module implements methods to read and write tabular data in CSV format.
#
# The csv module’s `reader()` and `writer()` methods read and write CSV files. You can also read and write data into dictionary form using the `DictReader()` and `DictWriter()` methods.
#
# For more information about this built-in Python library go to [CSV File Reading and Writing documentation](https://docs.python.org/3/library/csv.html).
#
# Let's now read our `data/genes.txt` tab separated file using the `csv` module into a dictionary based on the column headers using `csv.DictReader()`.
#
# |gene |	chrom |	start |	end |
# |-- | -- | -- | -- |
# |BRCA2 |	13 |	32889611 |	32973805 |
# |TNFAIP3 |	6 |	138188351 |	138204449 |
# |TCF7 |	5 |	133450402 |	133487556 |

# %% [markdown]
# First, import the `csv` module:

# %%
import csv

# %% [markdown]
# Read the data and store each dictionary into a list. Note that `DictReader()` returns an [ordered dictionary](https://docs.python.org/3/library/collections.html#ordereddict-objects).
#
# Ordered dictionaries are like regular dictionaries but they remember the order that items were inserted. When iterating over an ordered dictionary, the items are returned in the order their keys were first added.

# %%
data = []
with open("data/genes.txt") as f:
    reader = csv.DictReader(f, delimiter = "\t")
    for row in reader:
        print(row)
        data.append(row)

for d in data:
    print(d['chrom'], d['gene'], d['start'], d['end'])
# Out:
# {'end': '32973805', 'start': '32889611', 'chrom': '13', 'gene': 'BRCA2'}
# {'end': '138204449', 'start': '138188351', 'chrom': '6', 'gene': 'TNFAIP3'}
# {'end': '133487556', 'start': '133450402', 'chrom': '5', 'gene': 'TCF7'}
# 13 BRCA2 32889611 32973805
# 6 TNFAIP3 138188351 138204449
# 5 TCF7 133450402 133487556

# %% [markdown]
# data is a list of ordered dictionary representing each row of the data file:

# %%
# accessing first dictionary from the list
print(data[0])

# printing its keys
print(data[0].keys())

# its values
print(data[0].values())

# the value associated with the key 'gene'
print(data[0]['gene'])
# Out:
# {'end': '32973805', 'start': '32889611', 'chrom': '13', 'gene': 'BRCA2'}
# dict_keys(['end', 'start', 'chrom', 'gene'])
# dict_values(['32973805', '32889611', '13', 'BRCA2'])
# BRCA2

# %%
# looping over the list to print each gene
for d in data:
    print(d['gene'])

# %%
# calculating the length of each gene and adding its value into the dictionary
for d in data:
    d['len'] = int(d['end']) - int(d['start']) + 1
    print(d)

# %% [markdown]
# The main advantage of using the `DictReader()` method and the `csv` module is to write code that is easier to read and more flexible. Using the name of the column instead if its index make it more meaningful when reading code, and using this method of reading comma or tab separated files, give you the flexibility to add columns and changed their orders without having to modify your code.
#
# Let's have a look now at the file `data/genes_withstrand.txt` and spot the differences with `data/genes.txt`. Even though columns `chrom` and `gene` have been swapped and column `strand` added, the code written previously is still working.

# %%
data_withstrand = []
with open("data/genes_withstrand.txt") as f:
    reader = csv.DictReader(f, delimiter = "\t")
    for row in reader:
        print(row)
        data_withstrand.append(row)

for d in data_withstrand:
    print(d['chrom'], d['gene'], d['start'], d['end'])

# %%
# Write a delimited file using the csv module from a list of dictionaries 
with open("gene_lengths.txt", "w") as f:
    writer = csv.DictWriter(f, data[0].keys(), delimiter='\t')
    writer.writeheader() # write header

    for d in data:
        writer.writerow(d) # write row

# Open the output file and print out its content
with open("gene_lengths.txt") as f:
    for line in f:
        print(line.strip())
# Out:
# continent	country	pop	year	lifeExp	gdpPercap
# Asia	Afghanistan	8425333	1952	28.801	779.4453145
# Asia	Afghanistan	9240934	1957	30.332	820.8530296
# Asia	Afghanistan	10267083	1962	31.997	853.10071
# Asia	Afghanistan	11537966	1967	34.02	836.1971382
# Asia	Afghanistan	13079460	1972	36.088	739.9811058
# Asia	Afghanistan	14880372	1977	38.438	786.11336
# Asia	Afghanistan	12881816	1982	39.854	978.0114388
# Asia	Afghanistan	13867957	1987	40.822	852.3959448
# Asia	Afghanistan	16317921	1992	41.674	649.3413952
# Asia	Afghanistan	22227415	1997	41.763	635.341351
# Asia	Afghanistan	25268405	2002	42.129	726.7340548
# Asia	Afghanistan	31889923	2007	43.828	974.5803384
# Europe	Albania	1282697	1952	55.23	1601.056136
# Europe	Albania	1476505	1957	59.28	1942.284244
# Europe	Albania	1728137	1962	64.82	2312.888958
# Europe	Albania	1984060	1967	66.22	2760.196931
# Europe	Albania	2263554	1972	67.69	3313.422188
# Europe	Albania	2509048	1977	68.93	3533.00391
# Europe	Albania	2780097	1982	70.42	3630.880722
# Europe	Albania	3075321	1987	72	3738.932735
# Europe	Albania	3326498	1992	71.581	2497.437901
# Europe	Albania	3428038	1997	72.95	3193.054604
# Europe	Albania	3508512	2002	75.651	4604.211737
# Europe	Albania	3600523	2007	76.423	5937.029526
# Africa	Algeria	9279525	1952	43.077	2449.008185
# Africa	Algeria	10270856	1957	45.685	3013.976023
# Africa	Algeria	11000948	1962	48.303	2550.81688
# Africa	Algeria	12760499	1967	51.407	3246.991771
# Africa	Algeria	14760787	1972	54.518	4182.663766
# Africa	Algeria	17152804	1977	58.014	4910.416756
# Africa	Algeria	20033753	1982	61.368	5745.160213
# Africa	Algeria	23254956	1987	65.799	5681.358539
# Africa	Algeria	26298373	1992	67.744	5023.216647
# Africa	Algeria	29072015	1997	69.152	4797.295051
# Africa	Algeria	31287142	2002	70.994	5288.040382
# Africa	Algeria	33333216	2007	72.301	6223.367465
# Africa	Angola	4232095	1952	30.015	3520.610273
# Africa	Angola	4561361	1957	31.999	3827.940465
# Africa	Angola	4826015	1962	34	4269.276742
# Africa	Angola	5247469	1967	35.985	5522.776375
# Africa	Angola	5894858	1972	37.928	5473.288005
# Africa	Angola	6162675	1977	39.483	3008.647355
# Africa	Angola	7016384	1982	39.942	2756.953672
# Africa	Angola	7874230	1987	39.906	2430.208311
# Africa	Angola	8735988	1992	40.647	2627.845685
# Africa	Angola	9875024	1997	40.963	2277.140884
# Africa	Angola	10866106	2002	41.003	2773.287312
# Africa	Angola	12420476	2007	42.731	4797.231267
# Americas	Argentina	17876956	1952	62.485	5911.315053
# Americas	Argentina	19610538	1957	64.399	6856.856212
# Americas	Argentina	21283783	1962	65.142	7133.166023
# Americas	Argentina	22934225	1967	65.634	8052.953021
# Americas	Argentina	24779799	1972	67.065	9443.038526
# Americas	Argentina	26983828	1977	68.481	10079.02674
# Americas	Argentina	29341374	1982	69.942	8997.897412
# Americas	Argentina	31620918	1987	70.774	9139.671389
# Americas	Argentina	33958947	1992	71.868	9308.41871
# Americas	Argentina	36203463	1997	73.275	10967.28195
# Americas	Argentina	38331121	2002	74.34	8797.640716
# Americas	Argentina	40301927	2007	75.32	12779.37964
# Oceania	Australia	8691212	1952	69.12	10039.59564
# Oceania	Australia	9712569	1957	70.33	10949.64959
# Oceania	Australia	10794968	1962	70.93	12217.22686
# Oceania	Australia	11872264	1967	71.1	14526.12465
# Oceania	Australia	13177000	1972	71.93	16788.62948
# Oceania	Australia	14074100	1977	73.49	18334.19751
# Oceania	Australia	15184200	1982	74.74	19477.00928
# Oceania	Australia	16257249	1987	76.32	21888.88903
# Oceania	Australia	17481977	1992	77.56	23424.76683
# Oceania	Australia	18565243	1997	78.83	26997.93657
# Oceania	Australia	19546792	2002	80.37	30687.75473
# Oceania	Australia	20434176	2007	81.235	34435.36744
# Europe	Austria	6927772	1952	66.8	6137.076492
# Europe	Austria	6965860	1957	67.48	8842.59803
# Europe	Austria	7129864	1962	69.54	10750.72111
# Europe	Austria	7376998	1967	70.14	12834.6024
# Europe	Austria	7544201	1972	70.63	16661.6256
# Europe	Austria	7568430	1977	72.17	19749.4223
# Europe	Austria	7574613	1982	73.18	21597.08362
# Europe	Austria	7578903	1987	74.94	23687.82607
# Europe	Austria	7914969	1992	76.04	27042.01868
# Europe	Austria	8069876	1997	77.51	29095.92066
# Europe	Austria	8148312	2002	78.98	32417.60769
# Europe	Austria	8199783	2007	79.829	36126.4927
# Asia	Bahrain	120447	1952	50.939	9867.084765
# Asia	Bahrain	138655	1957	53.832	11635.79945
# Asia	Bahrain	171863	1962	56.923	12753.27514
# Asia	Bahrain	202182	1967	59.923	14804.6727
# Asia	Bahrain	230800	1972	63.3	18268.65839
# Asia	Bahrain	297410	1977	65.593	19340.10196
# Asia	Bahrain	377967	1982	69.052	19211.14731
# Asia	Bahrain	454612	1987	70.75	18524.02406
# Asia	Bahrain	529491	1992	72.601	19035.57917
# Asia	Bahrain	598561	1997	73.925	20292.01679
# Asia	Bahrain	656397	2002	74.795	23403.55927
# Asia	Bahrain	708573	2007	75.635	29796.04834
# Asia	Bangladesh	46886859	1952	37.484	684.2441716
# Asia	Bangladesh	51365468	1957	39.348	661.6374577
# Asia	Bangladesh	56839289	1962	41.216	686.3415538
# Asia	Bangladesh	62821884	1967	43.453	721.1860862
# Asia	Bangladesh	70759295	1972	45.252	630.2336265
# Asia	Bangladesh	80428306	1977	46.923	659.8772322
# Asia	Bangladesh	93074406	1982	50.009	676.9818656
# Asia	Bangladesh	103764241	1987	52.819	751.9794035
# Asia	Bangladesh	113704579	1992	56.018	837.8101643
# Asia	Bangladesh	123315288	1997	59.412	972.7700352
# Asia	Bangladesh	135656790	2002	62.013	1136.39043
# Asia	Bangladesh	150448339	2007	64.062	1391.253792
# Europe	Belgium	8730405	1952	68	8343.105127
# Europe	Belgium	8989111	1957	69.24	9714.960623
# Europe	Belgium	9218400	1962	70.25	10991.20676
# Europe	Belgium	9556500	1967	70.94	13149.04119
# Europe	Belgium	9709100	1972	71.44	16672.14356
# Europe	Belgium	9821800	1977	72.8	19117.97448
# Europe	Belgium	9856303	1982	73.93	20979.84589
# Europe	Belgium	9870200	1987	75.35	22525.56308
# Europe	Belgium	10045622	1992	76.46	25575.57069
# Europe	Belgium	10199787	1997	77.53	27561.19663
# Europe	Belgium	10311970	2002	78.32	30485.88375
# Europe	Belgium	10392226	2007	79.441	33692.60508
# Africa	Benin	1738315	1952	38.223	1062.7522
# Africa	Benin	1925173	1957	40.358	959.6010805
# Africa	Benin	2151895	1962	42.618	949.4990641
# Africa	Benin	2427334	1967	44.885	1035.831411
# Africa	Benin	2761407	1972	47.014	1085.796879
# Africa	Benin	3168267	1977	49.19	1029.161251
# Africa	Benin	3641603	1982	50.904	1277.897616
# Africa	Benin	4243788	1987	52.337	1225.85601
# Africa	Benin	4981671	1992	53.919	1191.207681
# Africa	Benin	6066080	1997	54.777	1232.975292
# Africa	Benin	7026113	2002	54.406	1372.877931
# Africa	Benin	8078314	2007	56.728	1441.284873
# Americas	Bolivia	2883315	1952	40.414	2677.326347
# Americas	Bolivia	3211738	1957	41.89	2127.686326
# Americas	Bolivia	3593918	1962	43.428	2180.972546
# Americas	Bolivia	4040665	1967	45.032	2586.886053
# Americas	Bolivia	4565872	1972	46.714	2980.331339
# Americas	Bolivia	5079716	1977	50.023	3548.097832
# Americas	Bolivia	5642224	1982	53.859	3156.510452
# Americas	Bolivia	6156369	1987	57.251	2753.69149
# Americas	Bolivia	6893451	1992	59.957	2961.699694
# Americas	Bolivia	7693188	1997	62.05	3326.143191
# Americas	Bolivia	8445134	2002	63.883	3413.26269
# Americas	Bolivia	9119152	2007	65.554	3822.137084
# Europe	Bosnia and Herzegovina	2791000	1952	53.82	973.5331948
# Europe	Bosnia and Herzegovina	3076000	1957	58.45	1353.989176
# Europe	Bosnia and Herzegovina	3349000	1962	61.93	1709.683679
# Europe	Bosnia and Herzegovina	3585000	1967	64.79	2172.352423
# Europe	Bosnia and Herzegovina	3819000	1972	67.45	2860.16975
# Europe	Bosnia and Herzegovina	4086000	1977	69.86	3528.481305
# Europe	Bosnia and Herzegovina	4172693	1982	70.69	4126.613157
# Europe	Bosnia and Herzegovina	4338977	1987	71.14	4314.114757
# Europe	Bosnia and Herzegovina	4256013	1992	72.178	2546.781445
# Europe	Bosnia and Herzegovina	3607000	1997	73.244	4766.355904
# Europe	Bosnia and Herzegovina	4165416	2002	74.09	6018.975239
# Europe	Bosnia and Herzegovina	4552198	2007	74.852	7446.298803
# Africa	Botswana	442308	1952	47.622	851.2411407
# Africa	Botswana	474639	1957	49.618	918.2325349
# Africa	Botswana	512764	1962	51.52	983.6539764
# Africa	Botswana	553541	1967	53.298	1214.709294
# Africa	Botswana	619351	1972	56.024	2263.611114
# Africa	Botswana	781472	1977	59.319	3214.857818
# Africa	Botswana	970347	1982	61.484	4551.14215
# Africa	Botswana	1151184	1987	63.622	6205.88385
# Africa	Botswana	1342614	1992	62.745	7954.111645
# Africa	Botswana	1536536	1997	52.556	8647.142313
# Africa	Botswana	1630347	2002	46.634	11003.60508
# Africa	Botswana	1639131	2007	50.728	12569.85177
# Americas	Brazil	56602560	1952	50.917	2108.944355
# Americas	Brazil	65551171	1957	53.285	2487.365989
# Americas	Brazil	76039390	1962	55.665	3336.585802
# Americas	Brazil	88049823	1967	57.632	3429.864357
# Americas	Brazil	100840058	1972	59.504	4985.711467
# Americas	Brazil	114313951	1977	61.489	6660.118654
# Americas	Brazil	128962939	1982	63.336	7030.835878
# Americas	Brazil	142938076	1987	65.205	7807.095818
# Americas	Brazil	155975974	1992	67.057	6950.283021
# Americas	Brazil	168546719	1997	69.388	7957.980824
# Americas	Brazil	179914212	2002	71.006	8131.212843
# Americas	Brazil	190010647	2007	72.39	9065.800825
# Europe	Bulgaria	7274900	1952	59.6	2444.286648
# Europe	Bulgaria	7651254	1957	66.61	3008.670727
# Europe	Bulgaria	8012946	1962	69.51	4254.337839
# Europe	Bulgaria	8310226	1967	70.42	5577.0028
# Europe	Bulgaria	8576200	1972	70.9	6597.494398
# Europe	Bulgaria	8797022	1977	70.81	7612.240438
# Europe	Bulgaria	8892098	1982	71.08	8224.191647
# Europe	Bulgaria	8971958	1987	71.34	8239.854824
# Europe	Bulgaria	8658506	1992	71.19	6302.623438
# Europe	Bulgaria	8066057	1997	70.32	5970.38876
# Europe	Bulgaria	7661799	2002	72.14	7696.777725
# Europe	Bulgaria	7322858	2007	73.005	10680.79282
# Africa	Burkina Faso	4469979	1952	31.975	543.2552413
# Africa	Burkina Faso	4713416	1957	34.906	617.1834648
# Africa	Burkina Faso	4919632	1962	37.814	722.5120206
# Africa	Burkina Faso	5127935	1967	40.697	794.8265597
# Africa	Burkina Faso	5433886	1972	43.591	854.7359763
# Africa	Burkina Faso	5889574	1977	46.137	743.3870368
# Africa	Burkina Faso	6634596	1982	48.122	807.1985855
# Africa	Burkina Faso	7586551	1987	49.557	912.0631417
# Africa	Burkina Faso	8878303	1992	50.26	931.7527731
# Africa	Burkina Faso	10352843	1997	50.324	946.2949618
# Africa	Burkina Faso	12251209	2002	50.65	1037.645221
# Africa	Burkina Faso	14326203	2007	52.295	1217.032994
# Africa	Burundi	2445618	1952	39.031	339.2964587
# Africa	Burundi	2667518	1957	40.533	379.5646281
# Africa	Burundi	2961915	1962	42.045	355.2032273
# Africa	Burundi	3330989	1967	43.548	412.9775136
# Africa	Burundi	3529983	1972	44.057	464.0995039
# Africa	Burundi	3834415	1977	45.91	556.1032651
# Africa	Burundi	4580410	1982	47.471	559.603231
# Africa	Burundi	5126023	1987	48.211	621.8188189
# Africa	Burundi	5809236	1992	44.736	631.6998778
# Africa	Burundi	6121610	1997	45.326	463.1151478
# Africa	Burundi	7021078	2002	47.36	446.4035126
# Africa	Burundi	8390505	2007	49.58	430.0706916
# Asia	Cambodia	4693836	1952	39.417	368.4692856
# Asia	Cambodia	5322536	1957	41.366	434.0383364
# Asia	Cambodia	6083619	1962	43.415	496.9136476
# Asia	Cambodia	6960067	1967	45.415	523.4323142
# Asia	Cambodia	7450606	1972	40.317	421.6240257
# Asia	Cambodia	6978607	1977	31.22	524.9721832
# Asia	Cambodia	7272485	1982	50.957	624.4754784
# Asia	Cambodia	8371791	1987	53.914	683.8955732
# Asia	Cambodia	10150094	1992	55.803	682.3031755
# Asia	Cambodia	11782962	1997	56.534	734.28517
# Asia	Cambodia	12926707	2002	56.752	896.2260153
# Asia	Cambodia	14131858	2007	59.723	1713.778686
# Africa	Cameroon	5009067	1952	38.523	1172.667655
# Africa	Cameroon	5359923	1957	40.428	1313.048099
# Africa	Cameroon	5793633	1962	42.643	1399.607441
# Africa	Cameroon	6335506	1967	44.799	1508.453148
# Africa	Cameroon	7021028	1972	47.049	1684.146528
# Africa	Cameroon	7959865	1977	49.355	1783.432873
# Africa	Cameroon	9250831	1982	52.961	2367.983282
# Africa	Cameroon	10780667	1987	54.985	2602.664206
# Africa	Cameroon	12467171	1992	54.314	1793.163278
# Africa	Cameroon	14195809	1997	52.199	1694.337469
# Africa	Cameroon	15929988	2002	49.856	1934.011449
# Africa	Cameroon	17696293	2007	50.43	2042.09524
# Americas	Canada	14785584	1952	68.75	11367.16112
# Americas	Canada	17010154	1957	69.96	12489.95006
# Americas	Canada	18985849	1962	71.3	13462.48555
# Americas	Canada	20819767	1967	72.13	16076.58803
# Americas	Canada	22284500	1972	72.88	18970.57086
# Americas	Canada	23796400	1977	74.21	22090.88306
# Americas	Canada	25201900	1982	75.76	22898.79214
# Americas	Canada	26549700	1987	76.86	26626.51503
# Americas	Canada	28523502	1992	77.95	26342.88426
# Americas	Canada	30305843	1997	78.61	28954.92589
# Americas	Canada	31902268	2002	79.77	33328.96507
# Americas	Canada	33390141	2007	80.653	36319.23501
# Africa	Central African Republic	1291695	1952	35.463	1071.310713
# Africa	Central African Republic	1392284	1957	37.464	1190.844328
# Africa	Central African Republic	1523478	1962	39.475	1193.068753
# Africa	Central African Republic	1733638	1967	41.478	1136.056615
# Africa	Central African Republic	1927260	1972	43.457	1070.013275
# Africa	Central African Republic	2167533	1977	46.775	1109.374338
# Africa	Central African Republic	2476971	1982	48.295	956.7529907
# Africa	Central African Republic	2840009	1987	50.485	844.8763504
# Africa	Central African Republic	3265124	1992	49.396	747.9055252
# Africa	Central African Republic	3696513	1997	46.066	740.5063317
# Africa	Central African Republic	4048013	2002	43.308	738.6906068
# Africa	Central African Republic	4369038	2007	44.741	706.016537
# Africa	Chad	2682462	1952	38.092	1178.665927
# Africa	Chad	2894855	1957	39.881	1308.495577
# Africa	Chad	3150417	1962	41.716	1389.817618
# Africa	Chad	3495967	1967	43.601	1196.810565
# Africa	Chad	3899068	1972	45.569	1104.103987
# Africa	Chad	4388260	1977	47.383	1133.98495
# Africa	Chad	4875118	1982	49.517	797.9081006
# Africa	Chad	5498955	1987	51.051	952.386129
# Africa	Chad	6429417	1992	51.724	1058.0643
# Africa	Chad	7562011	1997	51.573	1004.961353
# Africa	Chad	8835739	2002	50.525	1156.18186
# Africa	Chad	10238807	2007	50.651	1704.063724
# Americas	Chile	6377619	1952	54.745	3939.978789
# Americas	Chile	7048426	1957	56.074	4315.622723
# Americas	Chile	7961258	1962	57.924	4519.094331
# Americas	Chile	8858908	1967	60.523	5106.654313
# Americas	Chile	9717524	1972	63.441	5494.024437
# Americas	Chile	10599793	1977	67.052	4756.763836
# Americas	Chile	11487112	1982	70.565	5095.665738
# Americas	Chile	12463354	1987	72.492	5547.063754
# Americas	Chile	13572994	1992	74.126	7596.125964
# Americas	Chile	14599929	1997	75.816	10118.05318
# Americas	Chile	15497046	2002	77.86	10778.78385
# Americas	Chile	16284741	2007	78.553	13171.63885
# Asia	China	556263527	1952	44	400.448611
# Asia	China	637408000	1957	50.54896	575.9870009
# Asia	China	665770000	1962	44.50136	487.6740183
# Asia	China	754550000	1967	58.38112	612.7056934
# Asia	China	862030000	1972	63.11888	676.9000921
# Asia	China	943455000	1977	63.96736	741.2374699
# Asia	China	1000281000	1982	65.525	962.4213805
# Asia	China	1084035000	1987	67.274	1378.904018
# Asia	China	1164970000	1992	68.69	1655.784158
# Asia	China	1230075000	1997	70.426	2289.234136
# Asia	China	1280400000	2002	72.028	3119.280896
# Asia	China	1318683096	2007	72.961	4959.114854
# Americas	Colombia	12350771	1952	50.643	2144.115096
# Americas	Colombia	14485993	1957	55.118	2323.805581
# Americas	Colombia	17009885	1962	57.863	2492.351109
# Americas	Colombia	19764027	1967	59.963	2678.729839
# Americas	Colombia	22542890	1972	61.623	3264.660041
# Americas	Colombia	25094412	1977	63.837	3815.80787
# Americas	Colombia	27764644	1982	66.653	4397.575659
# Americas	Colombia	30964245	1987	67.768	4903.2191
# Americas	Colombia	34202721	1992	68.421	5444.648617
# Americas	Colombia	37657830	1997	70.313	6117.361746
# Americas	Colombia	41008227	2002	71.682	5755.259962
# Americas	Colombia	44227550	2007	72.889	7006.580419
# Africa	Comoros	153936	1952	40.715	1102.990936
# Africa	Comoros	170928	1957	42.46	1211.148548
# Africa	Comoros	191689	1962	44.467	1406.648278
# Africa	Comoros	217378	1967	46.472	1876.029643
# Africa	Comoros	250027	1972	48.944	1937.577675
# Africa	Comoros	304739	1977	50.939	1172.603047
# Africa	Comoros	348643	1982	52.933	1267.100083
# Africa	Comoros	395114	1987	54.926	1315.980812
# Africa	Comoros	454429	1992	57.939	1246.90737
# Africa	Comoros	527982	1997	60.66	1173.618235
# Africa	Comoros	614382	2002	62.974	1075.811558
# Africa	Comoros	710960	2007	65.152	986.1478792
# Africa	Congo Rep Dem	14100005	1952	39.143	780.5423257
# Africa	Congo Rep Dem	15577932	1957	40.652	905.8602303
# Africa	Congo Rep Dem	17486434	1962	42.122	896.3146335
# Africa	Congo Rep Dem	19941073	1967	44.056	861.5932424
# Africa	Congo Rep Dem	23007669	1972	45.989	904.8960685
# Africa	Congo Rep Dem	26480870	1977	47.804	795.757282
# Africa	Congo Rep Dem	30646495	1982	47.784	673.7478181
# Africa	Congo Rep Dem	35481645	1987	47.412	672.774812
# Africa	Congo Rep Dem	41672143	1992	45.548	457.7191807
# Africa	Congo Rep Dem	47798986	1997	42.587	312.188423
# Africa	Congo Rep Dem	55379852	2002	44.966	241.1658765
# Africa	Congo Rep Dem	64606759	2007	46.462	277.5518587
# Americas	Costa Rica	926317	1952	57.206	2627.009471
# Americas	Costa Rica	1112300	1957	60.026	2990.010802
# Americas	Costa Rica	1345187	1962	62.842	3460.937025
# Americas	Costa Rica	1588717	1967	65.424	4161.727834
# Americas	Costa Rica	1834796	1972	67.849	5118.146939
# Americas	Costa Rica	2108457	1977	70.75	5926.876967
# Americas	Costa Rica	2424367	1982	73.45	5262.734751
# Americas	Costa Rica	2799811	1987	74.752	5629.915318
# Americas	Costa Rica	3173216	1992	75.713	6160.416317
# Americas	Costa Rica	3518107	1997	77.26	6677.045314
# Americas	Costa Rica	3834934	2002	78.123	7723.447195
# Americas	Costa Rica	4133884	2007	78.782	9645.06142
# Africa	Cote Ivoire	2977019	1952	40.477	1388.594732
# Africa	Cote Ivoire	3300000	1957	42.469	1500.895925
# Africa	Cote Ivoire	3832408	1962	44.93	1728.869428
# Africa	Cote Ivoire	4744870	1967	47.35	2052.050473
# Africa	Cote Ivoire	6071696	1972	49.801	2378.201111
# Africa	Cote Ivoire	7459574	1977	52.374	2517.736547
# Africa	Cote Ivoire	9025951	1982	53.983	2602.710169
# Africa	Cote Ivoire	10761098	1987	54.655	2156.956069
# Africa	Cote Ivoire	12772596	1992	52.044	1648.073791
# Africa	Cote Ivoire	14625967	1997	47.991	1786.265407
# Africa	Cote Ivoire	16252726	2002	46.832	1648.800823
# Africa	Cote Ivoire	18013409	2007	48.328	1544.750112
# Europe	Croatia	3882229	1952	61.21	3119.23652
# Europe	Croatia	3991242	1957	64.77	4338.231617
# Europe	Croatia	4076557	1962	67.13	5477.890018
# Europe	Croatia	4174366	1967	68.5	6960.297861
# Europe	Croatia	4225310	1972	69.61	9164.090127
# Europe	Croatia	4318673	1977	70.64	11305.38517
# Europe	Croatia	4413368	1982	70.46	13221.82184
# Europe	Croatia	4484310	1987	71.52	13822.58394
# Europe	Croatia	4494013	1992	72.527	8447.794873
# Europe	Croatia	4444595	1997	73.68	9875.604515
# Europe	Croatia	4481020	2002	74.876	11628.38895
# Europe	Croatia	4493312	2007	75.748	14619.22272
# Americas	Cuba	6007797	1952	59.421	5586.53878
# Americas	Cuba	6640752	1957	62.325	6092.174359
# Americas	Cuba	7254373	1962	65.246	5180.75591
# Americas	Cuba	8139332	1967	68.29	5690.268015
# Americas	Cuba	8831348	1972	70.723	5305.445256
# Americas	Cuba	9537988	1977	72.649	6380.494966
# Americas	Cuba	9789224	1982	73.717	7316.918107
# Americas	Cuba	10239839	1987	74.174	7532.924763
# Americas	Cuba	10723260	1992	74.414	5592.843963
# Americas	Cuba	10983007	1997	76.151	5431.990415
# Americas	Cuba	11226999	2002	77.158	6340.646683
# Americas	Cuba	11416987	2007	78.273	8948.102923
# Europe	Czech Republic	9125183	1952	66.87	6876.14025
# Europe	Czech Republic	9513758	1957	69.03	8256.343918
# Europe	Czech Republic	9620282	1962	69.9	10136.86713
# Europe	Czech Republic	9835109	1967	70.38	11399.44489
# Europe	Czech Republic	9862158	1972	70.29	13108.4536
# Europe	Czech Republic	10161915	1977	70.71	14800.16062
# Europe	Czech Republic	10303704	1982	70.96	15377.22855
# Europe	Czech Republic	10311597	1987	71.58	16310.4434
# Europe	Czech Republic	10315702	1992	72.4	14297.02122
# Europe	Czech Republic	10300707	1997	74.01	16048.51424
# Europe	Czech Republic	10256295	2002	75.51	17596.21022
# Europe	Czech Republic	10228744	2007	76.486	22833.30851
# Europe	Denmark	4334000	1952	70.78	9692.385245
# Europe	Denmark	4487831	1957	71.81	11099.65935
# Europe	Denmark	4646899	1962	72.35	13583.31351
# Europe	Denmark	4838800	1967	72.96	15937.21123
# Europe	Denmark	4991596	1972	73.47	18866.20721
# Europe	Denmark	5088419	1977	74.69	20422.9015
# Europe	Denmark	5117810	1982	74.63	21688.04048
# Europe	Denmark	5127024	1987	74.8	25116.17581
# Europe	Denmark	5171393	1992	75.33	26406.73985
# Europe	Denmark	5283663	1997	76.11	29804.34567
# Europe	Denmark	5374693	2002	77.18	32166.50006
# Europe	Denmark	5468120	2007	78.332	35278.41874
# Africa	Djibouti	63149	1952	34.812	2669.529475
# Africa	Djibouti	71851	1957	37.328	2864.969076
# Africa	Djibouti	89898	1962	39.693	3020.989263
# Africa	Djibouti	127617	1967	42.074	3020.050513
# Africa	Djibouti	178848	1972	44.366	3694.212352
# Africa	Djibouti	228694	1977	46.519	3081.761022
# Africa	Djibouti	305991	1982	48.812	2879.468067
# Africa	Djibouti	311025	1987	50.04	2880.102568
# Africa	Djibouti	384156	1992	51.604	2377.156192
# Africa	Djibouti	417908	1997	53.157	1895.016984
# Africa	Djibouti	447416	2002	53.373	1908.260867
# Africa	Djibouti	496374	2007	54.791	2082.481567
# Americas	Dominican Republic	2491346	1952	45.928	1397.717137
# Americas	Dominican Republic	2923186	1957	49.828	1544.402995
# Americas	Dominican Republic	3453434	1962	53.459	1662.137359
# Americas	Dominican Republic	4049146	1967	56.751	1653.723003
# Americas	Dominican Republic	4671329	1972	59.631	2189.874499
# Americas	Dominican Republic	5302800	1977	61.788	2681.9889
# Americas	Dominican Republic	5968349	1982	63.727	2861.092386
# Americas	Dominican Republic	6655297	1987	66.046	2899.842175
# Americas	Dominican Republic	7351181	1992	68.457	3044.214214
# Americas	Dominican Republic	7992357	1997	69.957	3614.101285
# Americas	Dominican Republic	8650322	2002	70.847	4563.808154
# Americas	Dominican Republic	9319622	2007	72.235	6025.374752
# Americas	Ecuador	3548753	1952	48.357	3522.110717
# Americas	Ecuador	4058385	1957	51.356	3780.546651
# Americas	Ecuador	4681707	1962	54.64	4086.114078
# Americas	Ecuador	5432424	1967	56.678	4579.074215
# Americas	Ecuador	6298651	1972	58.796	5280.99471
# Americas	Ecuador	7278866	1977	61.31	6679.62326
# Americas	Ecuador	8365850	1982	64.342	7213.791267
# Americas	Ecuador	9545158	1987	67.231	6481.776993
# Americas	Ecuador	10748394	1992	69.613	7103.702595
# Americas	Ecuador	11911819	1997	72.312	7429.455877
# Americas	Ecuador	12921234	2002	74.173	5773.044512
# Americas	Ecuador	13755680	2007	74.994	6873.262326
# Africa	Egypt	22223309	1952	41.893	1418.822445
# Africa	Egypt	25009741	1957	44.444	1458.915272
# Africa	Egypt	28173309	1962	46.992	1693.335853
# Africa	Egypt	31681188	1967	49.293	1814.880728
# Africa	Egypt	34807417	1972	51.137	2024.008147
# Africa	Egypt	38783863	1977	53.319	2785.493582
# Africa	Egypt	45681811	1982	56.006	3503.729636
# Africa	Egypt	52799062	1987	59.797	3885.46071
# Africa	Egypt	59402198	1992	63.674	3794.755195
# Africa	Egypt	66134291	1997	67.217	4173.181797
# Africa	Egypt	73312559	2002	69.806	4754.604414
# Africa	Egypt	80264543	2007	71.338	5581.180998
# Americas	El Salvador	2042865	1952	45.262	3048.3029
# Americas	El Salvador	2355805	1957	48.57	3421.523218
# Americas	El Salvador	2747687	1962	52.307	3776.803627
# Americas	El Salvador	3232927	1967	55.855	4358.595393
# Americas	El Salvador	3790903	1972	58.207	4520.246008
# Americas	El Salvador	4282586	1977	56.696	5138.922374
# Americas	El Salvador	4474873	1982	56.604	4098.344175
# Americas	El Salvador	4842194	1987	63.154	4140.442097
# Americas	El Salvador	5274649	1992	66.798	4444.2317
# Americas	El Salvador	5783439	1997	69.535	5154.825496
# Americas	El Salvador	6353681	2002	70.734	5351.568666
# Americas	El Salvador	6939688	2007	71.878	5728.353514
# Africa	Equatorial Guinea	216964	1952	34.482	375.6431231
# Africa	Equatorial Guinea	232922	1957	35.983	426.0964081
# Africa	Equatorial Guinea	249220	1962	37.485	582.8419714
# Africa	Equatorial Guinea	259864	1967	38.987	915.5960025
# Africa	Equatorial Guinea	277603	1972	40.516	672.4122571
# Africa	Equatorial Guinea	192675	1977	42.024	958.5668124
# Africa	Equatorial Guinea	285483	1982	43.662	927.8253427
# Africa	Equatorial Guinea	341244	1987	45.664	966.8968149
# Africa	Equatorial Guinea	387838	1992	47.545	1132.055034
# Africa	Equatorial Guinea	439971	1997	48.245	2814.480755
# Africa	Equatorial Guinea	495627	2002	49.348	7703.4959
# Africa	Equatorial Guinea	551201	2007	51.579	12154.08975
# Africa	Eritrea	1438760	1952	35.928	328.9405571
# Africa	Eritrea	1542611	1957	38.047	344.1618859
# Africa	Eritrea	1666618	1962	40.158	380.9958433
# Africa	Eritrea	1820319	1967	42.189	468.7949699
# Africa	Eritrea	2260187	1972	44.142	514.3242082
# Africa	Eritrea	2512642	1977	44.535	505.7538077
# Africa	Eritrea	2637297	1982	43.89	524.8758493
# Africa	Eritrea	2915959	1987	46.453	521.1341333
# Africa	Eritrea	3668440	1992	49.991	582.8585102
# Africa	Eritrea	4058319	1997	53.378	913.47079
# Africa	Eritrea	4414865	2002	55.24	765.3500015
# Africa	Eritrea	4906585	2007	58.04	641.3695236
# Africa	Ethiopia	20860941	1952	34.078	362.1462796
# Africa	Ethiopia	22815614	1957	36.667	378.9041632
# Africa	Ethiopia	25145372	1962	40.059	419.4564161
# Africa	Ethiopia	27860297	1967	42.115	516.1186438
# Africa	Ethiopia	30770372	1972	43.515	566.2439442
# Africa	Ethiopia	34617799	1977	44.51	556.8083834
# Africa	Ethiopia	38111756	1982	44.916	577.8607471
# Africa	Ethiopia	42999530	1987	46.684	573.7413142
# Africa	Ethiopia	52088559	1992	48.091	421.3534653
# Africa	Ethiopia	59861301	1997	49.402	515.8894013
# Africa	Ethiopia	67946797	2002	50.725	530.0535319
# Africa	Ethiopia	76511887	2007	52.947	690.8055759
# Europe	Finland	4090500	1952	66.55	6424.519071
# Europe	Finland	4324000	1957	67.49	7545.415386
# Europe	Finland	4491443	1962	68.75	9371.842561
# Europe	Finland	4605744	1967	69.83	10921.63626
# Europe	Finland	4639657	1972	70.87	14358.8759
# Europe	Finland	4738902	1977	72.52	15605.42283
# Europe	Finland	4826933	1982	74.55	18533.15761
# Europe	Finland	4931729	1987	74.83	21141.01223
# Europe	Finland	5041039	1992	75.7	20647.16499
# Europe	Finland	5134406	1997	77.13	23723.9502
# Europe	Finland	5193039	2002	78.37	28204.59057
# Europe	Finland	5238460	2007	79.313	33207.0844
# Europe	France	42459667	1952	67.41	7029.809327
# Europe	France	44310863	1957	68.93	8662.834898
# Europe	France	47124000	1962	70.51	10560.48553
# Europe	France	49569000	1967	71.55	12999.91766
# Europe	France	51732000	1972	72.38	16107.19171
# Europe	France	53165019	1977	73.83	18292.63514
# Europe	France	54433565	1982	74.89	20293.89746
# Europe	France	55630100	1987	76.34	22066.44214
# Europe	France	57374179	1992	77.46	24703.79615
# Europe	France	58623428	1997	78.64	25889.78487
# Europe	France	59925035	2002	79.59	28926.03234
# Europe	France	61083916	2007	80.657	30470.0167
# Africa	Gabon	420702	1952	37.003	4293.476475
# Africa	Gabon	434904	1957	38.999	4976.198099
# Africa	Gabon	455661	1962	40.489	6631.459222
# Africa	Gabon	489004	1967	44.598	8358.761987
# Africa	Gabon	537977	1972	48.69	11401.94841
# Africa	Gabon	706367	1977	52.79	21745.57328
# Africa	Gabon	753874	1982	56.564	15113.36194
# Africa	Gabon	880397	1987	60.19	11864.40844
# Africa	Gabon	985739	1992	61.366	13522.15752
# Africa	Gabon	1126189	1997	60.461	14722.84188
# Africa	Gabon	1299304	2002	56.761	12521.71392
# Africa	Gabon	1454867	2007	56.735	13206.48452
# Africa	Gambia	284320	1952	30	485.2306591
# Africa	Gambia	323150	1957	32.065	520.9267111
# Africa	Gambia	374020	1962	33.896	599.650276
# Africa	Gambia	439593	1967	35.857	734.7829124
# Africa	Gambia	517101	1972	38.308	756.0868363
# Africa	Gambia	608274	1977	41.842	884.7552507
# Africa	Gambia	715523	1982	45.58	835.8096108
# Africa	Gambia	848406	1987	49.265	611.6588611
# Africa	Gambia	1025384	1992	52.644	665.6244126
# Africa	Gambia	1235767	1997	55.861	653.7301704
# Africa	Gambia	1457766	2002	58.041	660.5855997
# Africa	Gambia	1688359	2007	59.448	752.7497265
# Europe	Germany	69145952	1952	67.5	7144.114393
# Europe	Germany	71019069	1957	69.1	10187.82665
# Europe	Germany	73739117	1962	70.3	12902.46291
# Europe	Germany	76368453	1967	70.8	14745.62561
# Europe	Germany	78717088	1972	71	18016.18027
# Europe	Germany	78160773	1977	72.5	20512.92123
# Europe	Germany	78335266	1982	73.8	22031.53274
# Europe	Germany	77718298	1987	74.847	24639.18566
# Europe	Germany	80597764	1992	76.07	26505.30317
# Europe	Germany	82011073	1997	77.34	27788.88416
# Europe	Germany	82350671	2002	78.67	30035.80198
# Europe	Germany	82400996	2007	79.406	32170.37442
# Africa	Ghana	5581001	1952	43.149	911.2989371
# Africa	Ghana	6391288	1957	44.779	1043.561537
# Africa	Ghana	7355248	1962	46.452	1190.041118
# Africa	Ghana	8490213	1967	48.072	1125.69716
# Africa	Ghana	9354120	1972	49.875	1178.223708
# Africa	Ghana	10538093	1977	51.756	993.2239571
# Africa	Ghana	11400338	1982	53.744	876.032569
# Africa	Ghana	14168101	1987	55.729	847.0061135
# Africa	Ghana	16278738	1992	57.501	925.060154
# Africa	Ghana	18418288	1997	58.556	1005.245812
# Africa	Ghana	20550751	2002	58.453	1111.984578
# Africa	Ghana	22873338	2007	60.022	1327.60891
# Europe	Greece	7733250	1952	65.86	3530.690067
# Europe	Greece	8096218	1957	67.86	4916.299889
# Europe	Greece	8448233	1962	69.51	6017.190733
# Europe	Greece	8716441	1967	71	8513.097016
# Europe	Greece	8888628	1972	72.34	12724.82957
# Europe	Greece	9308479	1977	73.68	14195.52428
# Europe	Greece	9786480	1982	75.24	15268.42089
# Europe	Greece	9974490	1987	76.67	16120.52839
# Europe	Greece	10325429	1992	77.03	17541.49634
# Europe	Greece	10502372	1997	77.869	18747.69814
# Europe	Greece	10603863	2002	78.256	22514.2548
# Europe	Greece	10706290	2007	79.483	27538.41188
# Americas	Guatemala	3146381	1952	42.023	2428.237769
# Americas	Guatemala	3640876	1957	44.142	2617.155967
# Americas	Guatemala	4208858	1962	46.954	2750.364446
# Americas	Guatemala	4690773	1967	50.016	3242.531147
# Americas	Guatemala	5149581	1972	53.738	4031.408271
# Americas	Guatemala	5703430	1977	56.029	4879.992748
# Americas	Guatemala	6395630	1982	58.137	4820.49479
# Americas	Guatemala	7326406	1987	60.782	4246.485974
# Americas	Guatemala	8486949	1992	63.373	4439.45084
# Americas	Guatemala	9803875	1997	66.322	4684.313807
# Americas	Guatemala	11178650	2002	68.978	4858.347495
# Americas	Guatemala	12572928	2007	70.259	5186.050003
# Africa	Guinea	2664249	1952	33.609	510.1964923
# Africa	Guinea	2876726	1957	34.558	576.2670245
# Africa	Guinea	3140003	1962	35.753	686.3736739
# Africa	Guinea	3451418	1967	37.197	708.7595409
# Africa	Guinea	3811387	1972	38.842	741.6662307
# Africa	Guinea	4227026	1977	40.762	874.6858643
# Africa	Guinea	4710497	1982	42.891	857.2503577
# Africa	Guinea	5650262	1987	45.552	805.5724718
# Africa	Guinea	6990574	1992	48.576	794.3484384
# Africa	Guinea	8048834	1997	51.455	869.4497668
# Africa	Guinea	8807818	2002	53.676	945.5835837
# Africa	Guinea	9947814	2007	56.007	942.6542111
# Africa	Guinea Bissau	580653	1952	32.5	299.850319
# Africa	Guinea Bissau	601095	1957	33.489	431.7904566
# Africa	Guinea Bissau	627820	1962	34.488	522.0343725
# Africa	Guinea Bissau	601287	1967	35.492	715.5806402
# Africa	Guinea Bissau	625361	1972	36.486	820.2245876
# Africa	Guinea Bissau	745228	1977	37.465	764.7259628
# Africa	Guinea Bissau	825987	1982	39.327	838.1239671
# Africa	Guinea Bissau	927524	1987	41.245	736.4153921
# Africa	Guinea Bissau	1050938	1992	43.266	745.5398706
# Africa	Guinea Bissau	1193708	1997	44.873	796.6644681
# Africa	Guinea Bissau	1332459	2002	45.504	575.7047176
# Africa	Guinea Bissau	1472041	2007	46.388	579.231743
# Americas	Haiti	3201488	1952	37.579	1840.366939
# Americas	Haiti	3507701	1957	40.696	1726.887882
# Americas	Haiti	3880130	1962	43.59	1796.589032
# Americas	Haiti	4318137	1967	46.243	1452.057666
# Americas	Haiti	4698301	1972	48.042	1654.456946
# Americas	Haiti	4908554	1977	49.923	1874.298931
# Americas	Haiti	5198399	1982	51.461	2011.159549
# Americas	Haiti	5756203	1987	53.636	1823.015995
# Americas	Haiti	6326682	1992	55.089	1456.309517
# Americas	Haiti	6913545	1997	56.671	1341.726931
# Americas	Haiti	7607651	2002	58.137	1270.364932
# Americas	Haiti	8502814	2007	60.916	1201.637154
# Americas	Honduras	1517453	1952	41.912	2194.926204
# Americas	Honduras	1770390	1957	44.665	2220.487682
# Americas	Honduras	2090162	1962	48.041	2291.156835
# Americas	Honduras	2500689	1967	50.924	2538.269358
# Americas	Honduras	2965146	1972	53.884	2529.842345
# Americas	Honduras	3055235	1977	57.402	3203.208066
# Americas	Honduras	3669448	1982	60.909	3121.760794
# Americas	Honduras	4372203	1987	64.492	3023.096699
# Americas	Honduras	5077347	1992	66.399	3081.694603
# Americas	Honduras	5867957	1997	67.659	3160.454906
# Americas	Honduras	6677328	2002	68.565	3099.72866
# Americas	Honduras	7483763	2007	70.198	3548.330846
# Asia	Hong Kong China	2125900	1952	60.96	3054.421209
# Asia	Hong Kong China	2736300	1957	64.75	3629.076457
# Asia	Hong Kong China	3305200	1962	67.65	4692.648272
# Asia	Hong Kong China	3722800	1967	70	6197.962814
# Asia	Hong Kong China	4115700	1972	72	8315.928145
# Asia	Hong Kong China	4583700	1977	73.6	11186.14125
# Asia	Hong Kong China	5264500	1982	75.45	14560.53051
# Asia	Hong Kong China	5584510	1987	76.2	20038.47269
# Asia	Hong Kong China	5829696	1992	77.601	24757.60301
# Asia	Hong Kong China	6495918	1997	80	28377.63219
# Asia	Hong Kong China	6762476	2002	81.495	30209.01516
# Asia	Hong Kong China	6980412	2007	82.208	39724.97867
# Europe	Hungary	9504000	1952	64.03	5263.673816
# Europe	Hungary	9839000	1957	66.41	6040.180011
# Europe	Hungary	10063000	1962	67.96	7550.359877
# Europe	Hungary	10223422	1967	69.5	9326.64467
# Europe	Hungary	10394091	1972	69.76	10168.65611
# Europe	Hungary	10637171	1977	69.95	11674.83737
# Europe	Hungary	10705535	1982	69.39	12545.99066
# Europe	Hungary	10612740	1987	69.58	12986.47998
# Europe	Hungary	10348684	1992	69.17	10535.62855
# Europe	Hungary	10244684	1997	71.04	11712.7768
# Europe	Hungary	10083313	2002	72.59	14843.93556
# Europe	Hungary	9956108	2007	73.338	18008.94444
# Europe	Iceland	147962	1952	72.49	7267.688428
# Europe	Iceland	165110	1957	73.47	9244.001412
# Europe	Iceland	182053	1962	73.68	10350.15906
# Europe	Iceland	198676	1967	73.73	13319.89568
# Europe	Iceland	209275	1972	74.46	15798.06362
# Europe	Iceland	221823	1977	76.11	19654.96247
# Europe	Iceland	233997	1982	76.99	23269.6075
# Europe	Iceland	244676	1987	77.23	26923.20628
# Europe	Iceland	259012	1992	78.77	25144.39201
# Europe	Iceland	271192	1997	78.95	28061.09966
# Europe	Iceland	288030	2002	80.5	31163.20196
# Europe	Iceland	301931	2007	81.757	36180.78919
# Asia	India	372000000	1952	37.373	546.5657493
# Asia	India	409000000	1957	40.249	590.061996
# Asia	India	454000000	1962	43.605	658.3471509
# Asia	India	506000000	1967	47.193	700.7706107
# Asia	India	567000000	1972	50.651	724.032527
# Asia	India	634000000	1977	54.208	813.337323
# Asia	India	708000000	1982	56.596	855.7235377
# Asia	India	788000000	1987	58.553	976.5126756
# Asia	India	872000000	1992	60.223	1164.406809
# Asia	India	959000000	1997	61.765	1458.817442
# Asia	India	1034172547	2002	62.879	1746.769454
# Asia	India	1110396331	2007	64.698	2452.210407
# Asia	Indonesia	82052000	1952	37.468	749.6816546
# Asia	Indonesia	90124000	1957	39.918	858.9002707
# Asia	Indonesia	99028000	1962	42.518	849.2897701
# Asia	Indonesia	109343000	1967	45.964	762.4317721
# Asia	Indonesia	121282000	1972	49.203	1111.107907
# Asia	Indonesia	136725000	1977	52.702	1382.702056
# Asia	Indonesia	153343000	1982	56.159	1516.872988
# Asia	Indonesia	169276000	1987	60.137	1748.356961
# Asia	Indonesia	184816000	1992	62.681	2383.140898
# Asia	Indonesia	199278000	1997	66.041	3119.335603
# Asia	Indonesia	211060000	2002	68.588	2873.91287
# Asia	Indonesia	223547000	2007	70.65	3540.651564
# Asia	Iran	17272000	1952	44.869	3035.326002
# Asia	Iran	19792000	1957	47.181	3290.257643
# Asia	Iran	22874000	1962	49.325	4187.329802
# Asia	Iran	26538000	1967	52.469	5906.731805
# Asia	Iran	30614000	1972	55.234	9613.818607
# Asia	Iran	35480679	1977	57.702	11888.59508
# Asia	Iran	43072751	1982	59.62	7608.334602
# Asia	Iran	51889696	1987	63.04	6642.881371
# Asia	Iran	60397973	1992	65.742	7235.653188
# Asia	Iran	63327987	1997	68.042	8263.590301
# Asia	Iran	66907826	2002	69.451	9240.761975
# Asia	Iran	69453570	2007	70.964	11605.71449
# Asia	Iraq	5441766	1952	45.32	4129.766056
# Asia	Iraq	6248643	1957	48.437	6229.333562
# Asia	Iraq	7240260	1962	51.457	8341.737815
# Asia	Iraq	8519282	1967	54.459	8931.459811
# Asia	Iraq	10061506	1972	56.95	9576.037596
# Asia	Iraq	11882916	1977	60.413	14688.23507
# Asia	Iraq	14173318	1982	62.038	14517.90711
# Asia	Iraq	16543189	1987	65.044	11643.57268
# Asia	Iraq	17861905	1992	59.461	3745.640687
# Asia	Iraq	20775703	1997	58.811	3076.239795
# Asia	Iraq	24001816	2002	57.046	4390.717312
# Asia	Iraq	27499638	2007	59.545	4471.061906
# Europe	Ireland	2952156	1952	66.91	5210.280328
# Europe	Ireland	2878220	1957	68.9	5599.077872
# Europe	Ireland	2830000	1962	70.29	6631.597314
# Europe	Ireland	2900100	1967	71.08	7655.568963
# Europe	Ireland	3024400	1972	71.28	9530.772896
# Europe	Ireland	3271900	1977	72.03	11150.98113
# Europe	Ireland	3480000	1982	73.1	12618.32141
# Europe	Ireland	3539900	1987	74.36	13872.86652
# Europe	Ireland	3557761	1992	75.467	17558.81555
# Europe	Ireland	3667233	1997	76.122	24521.94713
# Europe	Ireland	3879155	2002	77.783	34077.04939
# Europe	Ireland	4109086	2007	78.885	40675.99635
# Asia	Israel	1620914	1952	65.39	4086.522128
# Asia	Israel	1944401	1957	67.84	5385.278451
# Asia	Israel	2310904	1962	69.39	7105.630706
# Asia	Israel	2693585	1967	70.75	8393.741404
# Asia	Israel	3095893	1972	71.63	12786.93223
# Asia	Israel	3495918	1977	73.06	13306.61921
# Asia	Israel	3858421	1982	74.45	15367.0292
# Asia	Israel	4203148	1987	75.6	17122.47986
# Asia	Israel	4936550	1992	76.93	18051.52254
# Asia	Israel	5531387	1997	78.269	20896.60924
# Asia	Israel	6029529	2002	79.696	21905.59514
# Asia	Israel	6426679	2007	80.745	25523.2771
# Europe	Italy	47666000	1952	65.94	4931.404155
# Europe	Italy	49182000	1957	67.81	6248.656232
# Europe	Italy	50843200	1962	69.24	8243.58234
# Europe	Italy	52667100	1967	71.06	10022.40131
# Europe	Italy	54365564	1972	72.19	12269.27378
# Europe	Italy	56059245	1977	73.48	14255.98475
# Europe	Italy	56535636	1982	74.98	16537.4835
# Europe	Italy	56729703	1987	76.42	19207.23482
# Europe	Italy	56840847	1992	77.44	22013.64486
# Europe	Italy	57479469	1997	78.82	24675.02446
# Europe	Italy	57926999	2002	80.24	27968.09817
# Europe	Italy	58147733	2007	80.546	28569.7197
# Americas	Jamaica	1426095	1952	58.53	2898.530881
# Americas	Jamaica	1535090	1957	62.61	4756.525781
# Americas	Jamaica	1665128	1962	65.61	5246.107524
# Americas	Jamaica	1861096	1967	67.51	6124.703451
# Americas	Jamaica	1997616	1972	69	7433.889293
# Americas	Jamaica	2156814	1977	70.11	6650.195573
# Americas	Jamaica	2298309	1982	71.21	6068.05135
# Americas	Jamaica	2326606	1987	71.77	6351.237495
# Americas	Jamaica	2378618	1992	71.766	7404.923685
# Americas	Jamaica	2531311	1997	72.262	7121.924704
# Americas	Jamaica	2664659	2002	72.047	6994.774861
# Americas	Jamaica	2780132	2007	72.567	7320.880262
# Asia	Japan	86459025	1952	63.03	3216.956347
# Asia	Japan	91563009	1957	65.5	4317.694365
# Asia	Japan	95831757	1962	68.73	6576.649461
# Asia	Japan	100825279	1967	71.43	9847.788607
# Asia	Japan	107188273	1972	73.42	14778.78636
# Asia	Japan	113872473	1977	75.38	16610.37701
# Asia	Japan	118454974	1982	77.11	19384.10571
# Asia	Japan	122091325	1987	78.67	22375.94189
# Asia	Japan	124329269	1992	79.36	26824.89511
# Asia	Japan	125956499	1997	80.69	28816.58499
# Asia	Japan	127065841	2002	82	28604.5919
# Asia	Japan	127467972	2007	82.603	31656.06806
# Asia	Jordan	607914	1952	43.158	1546.907807
# Asia	Jordan	746559	1957	45.669	1886.080591
# Asia	Jordan	933559	1962	48.126	2348.009158
# Asia	Jordan	1255058	1967	51.629	2741.796252
# Asia	Jordan	1613551	1972	56.528	2110.856309
# Asia	Jordan	1937652	1977	61.134	2852.351568
# Asia	Jordan	2347031	1982	63.739	4161.415959
# Asia	Jordan	2820042	1987	65.869	4448.679912
# Asia	Jordan	3867409	1992	68.015	3431.593647
# Asia	Jordan	4526235	1997	69.772	3645.379572
# Asia	Jordan	5307470	2002	71.263	3844.917194
# Asia	Jordan	6053193	2007	72.535	4519.461171
# Africa	Kenya	6464046	1952	42.27	853.540919
# Africa	Kenya	7454779	1957	44.686	944.4383152
# Africa	Kenya	8678557	1962	47.949	896.9663732
# Africa	Kenya	10191512	1967	50.654	1056.736457
# Africa	Kenya	12044785	1972	53.559	1222.359968
# Africa	Kenya	14500404	1977	56.155	1267.613204
# Africa	Kenya	17661452	1982	58.766	1348.225791
# Africa	Kenya	21198082	1987	59.339	1361.936856
# Africa	Kenya	25020539	1992	59.285	1341.921721
# Africa	Kenya	28263827	1997	54.407	1360.485021
# Africa	Kenya	31386842	2002	50.992	1287.514732
# Africa	Kenya	35610177	2007	54.11	1463.249282
# Asia	Korea Dem People Rep	8865488	1952	50.056	1088.277758
# Asia	Korea Dem People Rep	9411381	1957	54.081	1571.134655
# Asia	Korea Dem People Rep	10917494	1962	56.656	1621.693598
# Asia	Korea Dem People Rep	12617009	1967	59.942	2143.540609
# Asia	Korea Dem People Rep	14781241	1972	63.983	3701.621503
# Asia	Korea Dem People Rep	16325320	1977	67.159	4106.301249
# Asia	Korea Dem People Rep	17647518	1982	69.1	4106.525293
# Asia	Korea Dem People Rep	19067554	1987	70.647	4106.492315
# Asia	Korea Dem People Rep	20711375	1992	69.978	3726.063507
# Asia	Korea Dem People Rep	21585105	1997	67.727	1690.756814
# Asia	Korea Dem People Rep	22215365	2002	66.662	1646.758151
# Asia	Korea Dem People Rep	23301725	2007	67.297	1593.06548
# Asia	Korea Rep	20947571	1952	47.453	1030.592226
# Asia	Korea Rep	22611552	1957	52.681	1487.593537
# Asia	Korea Rep	26420307	1962	55.292	1536.344387
# Asia	Korea Rep	30131000	1967	57.716	2029.228142
# Asia	Korea Rep	33505000	1972	62.612	3030.87665
# Asia	Korea Rep	36436000	1977	64.766	4657.22102
# Asia	Korea Rep	39326000	1982	67.123	5622.942464
# Asia	Korea Rep	41622000	1987	69.81	8533.088805
# Asia	Korea Rep	43805450	1992	72.244	12104.27872
# Asia	Korea Rep	46173816	1997	74.647	15993.52796
# Asia	Korea Rep	47969150	2002	77.045	19233.98818
# Asia	Korea Rep	49044790	2007	78.623	23348.13973
# Asia	Kuwait	160000	1952	55.565	108382.3529
# Asia	Kuwait	212846	1957	58.033	113523.1329
# Asia	Kuwait	358266	1962	60.47	95458.11176
# Asia	Kuwait	575003	1967	64.624	80894.88326
# Asia	Kuwait	841934	1972	67.712	109347.867
# Asia	Kuwait	1140357	1977	69.343	59265.47714
# Asia	Kuwait	1497494	1982	71.309	31354.03573
# Asia	Kuwait	1891487	1987	74.174	28118.42998
# Asia	Kuwait	1418095	1992	75.19	34932.91959
# Asia	Kuwait	1765345	1997	76.156	40300.61996
# Asia	Kuwait	2111561	2002	76.904	35110.10566
# Asia	Kuwait	2505559	2007	77.588	47306.98978
# Asia	Lebanon	1439529	1952	55.928	4834.804067
# Asia	Lebanon	1647412	1957	59.489	6089.786934
# Asia	Lebanon	1886848	1962	62.094	5714.560611
# Asia	Lebanon	2186894	1967	63.87	6006.983042
# Asia	Lebanon	2680018	1972	65.421	7486.384341
# Asia	Lebanon	3115787	1977	66.099	8659.696836
# Asia	Lebanon	3086876	1982	66.983	7640.519521
# Asia	Lebanon	3089353	1987	67.926	5377.091329
# Asia	Lebanon	3219994	1992	69.292	6890.806854
# Asia	Lebanon	3430388	1997	70.265	8754.96385
# Asia	Lebanon	3677780	2002	71.028	9313.93883
# Asia	Lebanon	3921278	2007	71.993	10461.05868
# Africa	Lesotho	748747	1952	42.138	298.8462121
# Africa	Lesotho	813338	1957	45.047	335.9971151
# Africa	Lesotho	893143	1962	47.747	411.8006266
# Africa	Lesotho	996380	1967	48.492	498.6390265
# Africa	Lesotho	1116779	1972	49.767	496.5815922
# Africa	Lesotho	1251524	1977	52.208	745.3695408
# Africa	Lesotho	1411807	1982	55.078	797.2631074
# Africa	Lesotho	1599200	1987	57.18	773.9932141
# Africa	Lesotho	1803195	1992	59.685	977.4862725
# Africa	Lesotho	1982823	1997	55.558	1186.147994
# Africa	Lesotho	2046772	2002	44.593	1275.184575
# Africa	Lesotho	2012649	2007	42.592	1569.331442
# Africa	Liberia	863308	1952	38.48	575.5729961
# Africa	Liberia	975950	1957	39.486	620.9699901
# Africa	Liberia	1112796	1962	40.502	634.1951625
# Africa	Liberia	1279406	1967	41.536	713.6036483
# Africa	Liberia	1482628	1972	42.614	803.0054535
# Africa	Liberia	1703617	1977	43.764	640.3224383
# Africa	Liberia	1956875	1982	44.852	572.1995694
# Africa	Liberia	2269414	1987	46.027	506.1138573
# Africa	Liberia	1912974	1992	40.802	636.6229191
# Africa	Liberia	2200725	1997	42.221	609.1739508
# Africa	Liberia	2814651	2002	43.753	531.4823679
# Africa	Liberia	3193942	2007	45.678	414.5073415
# Africa	Libya	1019729	1952	42.723	2387.54806
# Africa	Libya	1201578	1957	45.289	3448.284395
# Africa	Libya	1441863	1962	47.808	6757.030816
# Africa	Libya	1759224	1967	50.227	18772.75169
# Africa	Libya	2183877	1972	52.773	21011.49721
# Africa	Libya	2721783	1977	57.442	21951.21176
# Africa	Libya	3344074	1982	62.155	17364.27538
# Africa	Libya	3799845	1987	66.234	11770.5898
# Africa	Libya	4364501	1992	68.755	9640.138501
# Africa	Libya	4759670	1997	71.555	9467.446056
# Africa	Libya	5368585	2002	72.737	9534.677467
# Africa	Libya	6036914	2007	73.952	12057.49928
# Africa	Madagascar	4762912	1952	36.681	1443.011715
# Africa	Madagascar	5181679	1957	38.865	1589.20275
# Africa	Madagascar	5703324	1962	40.848	1643.38711
# Africa	Madagascar	6334556	1967	42.881	1634.047282
# Africa	Madagascar	7082430	1972	44.851	1748.562982
# Africa	Madagascar	8007166	1977	46.881	1544.228586
# Africa	Madagascar	9171477	1982	48.969	1302.878658
# Africa	Madagascar	10568642	1987	49.35	1155.441948
# Africa	Madagascar	12210395	1992	52.214	1040.67619
# Africa	Madagascar	14165114	1997	54.978	986.2958956
# Africa	Madagascar	16473477	2002	57.286	894.6370822
# Africa	Madagascar	19167654	2007	59.443	1044.770126
# Africa	Malawi	2917802	1952	36.256	369.1650802
# Africa	Malawi	3221238	1957	37.207	416.3698064
# Africa	Malawi	3628608	1962	38.41	427.9010856
# Africa	Malawi	4147252	1967	39.487	495.5147806
# Africa	Malawi	4730997	1972	41.766	584.6219709
# Africa	Malawi	5637246	1977	43.767	663.2236766
# Africa	Malawi	6502825	1982	45.642	632.8039209
# Africa	Malawi	7824747	1987	47.457	635.5173634
# Africa	Malawi	10014249	1992	49.42	563.2000145
# Africa	Malawi	10419991	1997	47.495	692.2758103
# Africa	Malawi	11824495	2002	45.009	665.4231186
# Africa	Malawi	13327079	2007	48.303	759.3499101
# Asia	Malaysia	6748378	1952	48.463	1831.132894
# Asia	Malaysia	7739235	1957	52.102	1810.066992
# Asia	Malaysia	8906385	1962	55.737	2036.884944
# Asia	Malaysia	10154878	1967	59.371	2277.742396
# Asia	Malaysia	11441462	1972	63.01	2849.09478
# Asia	Malaysia	12845381	1977	65.256	3827.921571
# Asia	Malaysia	14441916	1982	68	4920.355951
# Asia	Malaysia	16331785	1987	69.5	5249.802653
# Asia	Malaysia	18319502	1992	70.693	7277.912802
# Asia	Malaysia	20476091	1997	71.938	10132.90964
# Asia	Malaysia	22662365	2002	73.044	10206.97794
# Asia	Malaysia	24821286	2007	74.241	12451.6558
# Africa	Mali	3838168	1952	33.685	452.3369807
# Africa	Mali	4241884	1957	35.307	490.3821867
# Africa	Mali	4690372	1962	36.936	496.1743428
# Africa	Mali	5212416	1967	38.487	545.0098873
# Africa	Mali	5828158	1972	39.977	581.3688761
# Africa	Mali	6491649	1977	41.714	686.3952693
# Africa	Mali	6998256	1982	43.916	618.0140641
# Africa	Mali	7634008	1987	46.364	684.1715576
# Africa	Mali	8416215	1992	48.388	739.014375
# Africa	Mali	9384984	1997	49.903	790.2579846
# Africa	Mali	10580176	2002	51.818	951.4097518
# Africa	Mali	12031795	2007	54.467	1042.581557
# Africa	Mauritania	1022556	1952	40.543	743.1159097
# Africa	Mauritania	1076852	1957	42.338	846.1202613
# Africa	Mauritania	1146757	1962	44.248	1055.896036
# Africa	Mauritania	1230542	1967	46.289	1421.145193
# Africa	Mauritania	1332786	1972	48.437	1586.851781
# Africa	Mauritania	1456688	1977	50.852	1497.492223
# Africa	Mauritania	1622136	1982	53.599	1481.150189
# Africa	Mauritania	1841240	1987	56.145	1421.603576
# Africa	Mauritania	2119465	1992	58.333	1361.369784
# Africa	Mauritania	2444741	1997	60.43	1483.136136
# Africa	Mauritania	2828858	2002	62.247	1579.019543
# Africa	Mauritania	3270065	2007	64.164	1803.151496
# Africa	Mauritius	516556	1952	50.986	1967.955707
# Africa	Mauritius	609816	1957	58.089	2034.037981
# Africa	Mauritius	701016	1962	60.246	2529.067487
# Africa	Mauritius	789309	1967	61.557	2475.387562
# Africa	Mauritius	851334	1972	62.944	2575.484158
# Africa	Mauritius	913025	1977	64.93	3710.982963
# Africa	Mauritius	992040	1982	66.711	3688.037739
# Africa	Mauritius	1042663	1987	68.74	4783.586903
# Africa	Mauritius	1096202	1992	69.745	6058.253846
# Africa	Mauritius	1149818	1997	70.736	7425.705295
# Africa	Mauritius	1200206	2002	71.954	9021.815894
# Africa	Mauritius	1250882	2007	72.801	10956.99112
# Americas	Mexico	30144317	1952	50.789	3478.125529
# Americas	Mexico	35015548	1957	55.19	4131.546641
# Americas	Mexico	41121485	1962	58.299	4581.609385
# Americas	Mexico	47995559	1967	60.11	5754.733883
# Americas	Mexico	55984294	1972	62.361	6809.40669
# Americas	Mexico	63759976	1977	65.032	7674.929108
# Americas	Mexico	71640904	1982	67.405	9611.147541
# Americas	Mexico	80122492	1987	69.498	8688.156003
# Americas	Mexico	88111030	1992	71.455	9472.384295
# Americas	Mexico	95895146	1997	73.67	9767.29753
# Americas	Mexico	102479927	2002	74.902	10742.44053
# Americas	Mexico	108700891	2007	76.195	11977.57496
# Asia	Mongolia	800663	1952	42.244	786.5668575
# Asia	Mongolia	882134	1957	45.248	912.6626085
# Asia	Mongolia	1010280	1962	48.251	1056.353958
# Asia	Mongolia	1149500	1967	51.253	1226.04113
# Asia	Mongolia	1320500	1972	53.754	1421.741975
# Asia	Mongolia	1528000	1977	55.491	1647.511665
# Asia	Mongolia	1756032	1982	57.489	2000.603139
# Asia	Mongolia	2015133	1987	60.222	2338.008304
# Asia	Mongolia	2312802	1992	61.271	1785.402016
# Asia	Mongolia	2494803	1997	63.625	1902.2521
# Asia	Mongolia	2674234	2002	65.033	2140.739323
# Asia	Mongolia	2874127	2007	66.803	3095.772271
# Europe	Montenegro	413834	1952	59.164	2647.585601
# Europe	Montenegro	442829	1957	61.448	3682.259903
# Europe	Montenegro	474528	1962	63.728	4649.593785
# Europe	Montenegro	501035	1967	67.178	5907.850937
# ...
# Europe	Slovak Republic	5199318	1987	71.08	12037.26758
# Europe	Slovak Republic	5302888	1992	71.38	9498.467723
# Europe	Slovak Republic	5383010	1997	72.71	12126.23065
# Europe	Slovak Republic	5410052	2002	73.8	13638.77837
# Europe	Slovak Republic	5447502	2007	74.663	18678.31435
# Europe	Slovenia	1489518	1952	65.57	4215.041741
# Europe	Slovenia	1533070	1957	67.85	5862.276629
# Europe	Slovenia	1582962	1962	69.15	7402.303395
# Europe	Slovenia	1646912	1967	69.18	9405.489397
# Europe	Slovenia	1694510	1972	69.82	12383.4862
# Europe	Slovenia	1746919	1977	70.97	15277.03017
# Europe	Slovenia	1861252	1982	71.063	17866.72175
# Europe	Slovenia	1945870	1987	72.25	18678.53492
# Europe	Slovenia	1999210	1992	73.64	14214.71681
# Europe	Slovenia	2011612	1997	75.13	17161.10735
# Europe	Slovenia	2011497	2002	76.66	20660.01936
# Europe	Slovenia	2009245	2007	77.926	25768.25759
# Africa	Somalia	2526994	1952	32.978	1135.749842
# Africa	Somalia	2780415	1957	34.977	1258.147413
# Africa	Somalia	3080153	1962	36.981	1369.488336
# Africa	Somalia	3428839	1967	38.977	1284.73318
# Africa	Somalia	3840161	1972	40.973	1254.576127
# Africa	Somalia	4353666	1977	41.974	1450.992513
# Africa	Somalia	5828892	1982	42.955	1176.807031
# Africa	Somalia	6921858	1987	44.501	1093.244963
# Africa	Somalia	6099799	1992	39.658	926.9602964
# Africa	Somalia	6633514	1997	43.795	930.5964284
# Africa	Somalia	7753310	2002	45.936	882.0818218
# Africa	Somalia	9118773	2007	48.159	926.1410683
# Africa	South Africa	14264935	1952	45.009	4725.295531
# Africa	South Africa	16151549	1957	47.985	5487.104219
# Africa	South Africa	18356657	1962	49.951	5768.729717
# Africa	South Africa	20997321	1967	51.927	7114.477971
# Africa	South Africa	23935810	1972	53.696	7765.962636
# Africa	South Africa	27129932	1977	55.527	8028.651439
# Africa	South Africa	31140029	1982	58.161	8568.266228
# Africa	South Africa	35933379	1987	60.834	7825.823398
# Africa	South Africa	39964159	1992	61.888	7225.069258
# Africa	South Africa	42835005	1997	60.236	7479.188244
# Africa	South Africa	44433622	2002	53.365	7710.946444
# Africa	South Africa	43997828	2007	49.339	9269.657808
# Europe	Spain	28549870	1952	64.94	3834.034742
# Europe	Spain	29841614	1957	66.66	4564.80241
# Europe	Spain	31158061	1962	69.69	5693.843879
# Europe	Spain	32850275	1967	71.44	7993.512294
# Europe	Spain	34513161	1972	73.06	10638.75131
# Europe	Spain	36439000	1977	74.39	13236.92117
# Europe	Spain	37983310	1982	76.3	13926.16997
# Europe	Spain	38880702	1987	76.9	15764.98313
# Europe	Spain	39549438	1992	77.57	18603.06452
# Europe	Spain	39855442	1997	78.77	20445.29896
# Europe	Spain	40152517	2002	79.78	24835.47166
# Europe	Spain	40448191	2007	80.941	28821.0637
# Asia	Sri Lanka	7982342	1952	57.593	1083.53203
# Asia	Sri Lanka	9128546	1957	61.456	1072.546602
# Asia	Sri Lanka	10421936	1962	62.192	1074.47196
# Asia	Sri Lanka	11737396	1967	64.266	1135.514326
# Asia	Sri Lanka	13016733	1972	65.042	1213.39553
# Asia	Sri Lanka	14116836	1977	65.949	1348.775651
# Asia	Sri Lanka	15410151	1982	68.757	1648.079789
# Asia	Sri Lanka	16495304	1987	69.011	1876.766827
# Asia	Sri Lanka	17587060	1992	70.379	2153.739222
# Asia	Sri Lanka	18698655	1997	70.457	2664.477257
# Asia	Sri Lanka	19576783	2002	70.815	3015.378833
# Asia	Sri Lanka	20378239	2007	72.396	3970.095407
# Africa	Sudan	8504667	1952	38.635	1615.991129
# Africa	Sudan	9753392	1957	39.624	1770.337074
# Africa	Sudan	11183227	1962	40.87	1959.593767
# Africa	Sudan	12716129	1967	42.858	1687.997641
# Africa	Sudan	14597019	1972	45.083	1659.652775
# Africa	Sudan	17104986	1977	47.8	2202.988423
# Africa	Sudan	20367053	1982	50.338	1895.544073
# Africa	Sudan	24725960	1987	51.744	1507.819159
# Africa	Sudan	28227588	1992	53.556	1492.197043
# Africa	Sudan	32160729	1997	55.373	1632.210764
# Africa	Sudan	37090298	2002	56.369	1993.398314
# Africa	Sudan	42292929	2007	58.556	2602.394995
# Africa	Swaziland	290243	1952	41.407	1148.376626
# Africa	Swaziland	326741	1957	43.424	1244.708364
# Africa	Swaziland	370006	1962	44.992	1856.182125
# Africa	Swaziland	420690	1967	46.633	2613.101665
# Africa	Swaziland	480105	1972	49.552	3364.836625
# Africa	Swaziland	551425	1977	52.537	3781.410618
# Africa	Swaziland	649901	1982	55.561	3895.384018
# Africa	Swaziland	779348	1987	57.678	3984.839812
# Africa	Swaziland	962344	1992	58.474	3553.0224
# Africa	Swaziland	1054486	1997	54.289	3876.76846
# Africa	Swaziland	1130269	2002	43.869	4128.116943
# Africa	Swaziland	1133066	2007	39.613	4513.480643
# Europe	Sweden	7124673	1952	71.86	8527.844662
# Europe	Sweden	7363802	1957	72.49	9911.878226
# Europe	Sweden	7561588	1962	73.37	12329.44192
# Europe	Sweden	7867931	1967	74.16	15258.29697
# Europe	Sweden	8122293	1972	74.72	17832.02464
# Europe	Sweden	8251648	1977	75.44	18855.72521
# Europe	Sweden	8325260	1982	76.42	20667.38125
# Europe	Sweden	8421403	1987	77.19	23586.92927
# Europe	Sweden	8718867	1992	78.16	23880.01683
# Europe	Sweden	8897619	1997	79.39	25266.59499
# Europe	Sweden	8954175	2002	80.04	29341.63093
# Europe	Sweden	9031088	2007	80.884	33859.74835
# Europe	Switzerland	4815000	1952	69.62	14734.23275
# Europe	Switzerland	5126000	1957	70.56	17909.48973
# Europe	Switzerland	5666000	1962	71.32	20431.0927
# Europe	Switzerland	6063000	1967	72.77	22966.14432
# Europe	Switzerland	6401400	1972	73.78	27195.11304
# Europe	Switzerland	6316424	1977	75.39	26982.29052
# Europe	Switzerland	6468126	1982	76.21	28397.71512
# Europe	Switzerland	6649942	1987	77.41	30281.70459
# Europe	Switzerland	6995447	1992	78.03	31871.5303
# Europe	Switzerland	7193761	1997	79.37	32135.32301
# Europe	Switzerland	7361757	2002	80.62	34480.95771
# Europe	Switzerland	7554661	2007	81.701	37506.41907
# Asia	Syria	3661549	1952	45.883	1643.485354
# Asia	Syria	4149908	1957	48.284	2117.234893
# Asia	Syria	4834621	1962	50.305	2193.037133
# Asia	Syria	5680812	1967	53.655	1881.923632
# Asia	Syria	6701172	1972	57.296	2571.423014
# Asia	Syria	7932503	1977	61.195	3195.484582
# Asia	Syria	9410494	1982	64.59	3761.837715
# Asia	Syria	11242847	1987	66.974	3116.774285
# Asia	Syria	13219062	1992	69.249	3340.542768
# Asia	Syria	15081016	1997	71.527	4014.238972
# Asia	Syria	17155814	2002	73.053	4090.925331
# Asia	Syria	19314747	2007	74.143	4184.548089
# Asia	Taiwan	8550362	1952	58.5	1206.947913
# Asia	Taiwan	10164215	1957	62.4	1507.86129
# Asia	Taiwan	11918938	1962	65.2	1822.879028
# Asia	Taiwan	13648692	1967	67.5	2643.858681
# Asia	Taiwan	15226039	1972	69.39	4062.523897
# Asia	Taiwan	16785196	1977	70.59	5596.519826
# Asia	Taiwan	18501390	1982	72.16	7426.354774
# Asia	Taiwan	19757799	1987	73.4	11054.56175
# Asia	Taiwan	20686918	1992	74.26	15215.6579
# Asia	Taiwan	21628605	1997	75.25	20206.82098
# Asia	Taiwan	22454239	2002	76.99	23235.42329
# Asia	Taiwan	23174294	2007	78.4	28718.27684
# Africa	Tanzania	8322925	1952	41.215	716.6500721
# Africa	Tanzania	9452826	1957	42.974	698.5356073
# Africa	Tanzania	10863958	1962	44.246	722.0038073
# Africa	Tanzania	12607312	1967	45.757	848.2186575
# Africa	Tanzania	14706593	1972	47.62	915.9850592
# Africa	Tanzania	17129565	1977	49.919	962.4922932
# Africa	Tanzania	19844382	1982	50.608	874.2426069
# Africa	Tanzania	23040630	1987	51.535	831.8220794
# Africa	Tanzania	26605473	1992	50.44	825.682454
# Africa	Tanzania	30686889	1997	48.466	789.1862231
# Africa	Tanzania	34593779	2002	49.651	899.0742111
# Africa	Tanzania	38139640	2007	52.517	1107.482182
# Asia	Thailand	21289402	1952	50.848	757.7974177
# Asia	Thailand	25041917	1957	53.63	793.5774148
# Asia	Thailand	29263397	1962	56.061	1002.199172
# Asia	Thailand	34024249	1967	58.285	1295.46066
# Asia	Thailand	39276153	1972	60.405	1524.358936
# Asia	Thailand	44148285	1977	62.494	1961.224635
# Asia	Thailand	48827160	1982	64.597	2393.219781
# Asia	Thailand	52910342	1987	66.084	2982.653773
# Asia	Thailand	56667095	1992	67.298	4616.896545
# Asia	Thailand	60216677	1997	67.521	5852.625497
# Asia	Thailand	62806748	2002	68.564	5913.187529
# Asia	Thailand	65068149	2007	70.616	7458.396327
# Africa	Togo	1219113	1952	38.596	859.8086567
# Africa	Togo	1357445	1957	41.208	925.9083202
# Africa	Togo	1528098	1962	43.922	1067.53481
# Africa	Togo	1735550	1967	46.769	1477.59676
# Africa	Togo	2056351	1972	49.759	1649.660188
# Africa	Togo	2308582	1977	52.887	1532.776998
# Africa	Togo	2644765	1982	55.471	1344.577953
# Africa	Togo	3154264	1987	56.941	1202.201361
# Africa	Togo	3747553	1992	58.061	1034.298904
# Africa	Togo	4320890	1997	58.39	982.2869243
# Africa	Togo	4977378	2002	57.561	886.2205765
# Africa	Togo	5701579	2007	58.42	882.9699438
# Americas	Trinidad and Tobago	662850	1952	59.1	3023.271928
# Americas	Trinidad and Tobago	764900	1957	61.8	4100.3934
# Americas	Trinidad and Tobago	887498	1962	64.9	4997.523971
# Americas	Trinidad and Tobago	960155	1967	65.4	5621.368472
# Americas	Trinidad and Tobago	975199	1972	65.9	6619.551419
# Americas	Trinidad and Tobago	1039009	1977	68.3	7899.554209
# Americas	Trinidad and Tobago	1116479	1982	68.832	9119.528607
# Americas	Trinidad and Tobago	1191336	1987	69.582	7388.597823
# Americas	Trinidad and Tobago	1183669	1992	69.862	7370.990932
# Americas	Trinidad and Tobago	1138101	1997	69.465	8792.573126
# Americas	Trinidad and Tobago	1101832	2002	68.976	11460.60023
# Americas	Trinidad and Tobago	1056608	2007	69.819	18008.50924
# Africa	Tunisia	3647735	1952	44.6	1468.475631
# Africa	Tunisia	3950849	1957	47.1	1395.232468
# Africa	Tunisia	4286552	1962	49.579	1660.30321
# Africa	Tunisia	4786986	1967	52.053	1932.360167
# Africa	Tunisia	5303507	1972	55.602	2753.285994
# Africa	Tunisia	6005061	1977	59.837	3120.876811
# Africa	Tunisia	6734098	1982	64.048	3560.233174
# Africa	Tunisia	7724976	1987	66.894	3810.419296
# Africa	Tunisia	8523077	1992	70.001	4332.720164
# Africa	Tunisia	9231669	1997	71.973	4876.798614
# Africa	Tunisia	9770575	2002	73.042	5722.895655
# Africa	Tunisia	10276158	2007	73.923	7092.923025
# Europe	Turkey	22235677	1952	43.585	1969.10098
# Europe	Turkey	25670939	1957	48.079	2218.754257
# Europe	Turkey	29788695	1962	52.098	2322.869908
# Europe	Turkey	33411317	1967	54.336	2826.356387
# Europe	Turkey	37492953	1972	57.005	3450.69638
# Europe	Turkey	42404033	1977	59.507	4269.122326
# Europe	Turkey	47328791	1982	61.036	4241.356344
# Europe	Turkey	52881328	1987	63.108	5089.043686
# Europe	Turkey	58179144	1992	66.146	5678.348271
# Europe	Turkey	63047647	1997	68.835	6601.429915
# Europe	Turkey	67308928	2002	70.845	6508.085718
# Europe	Turkey	71158647	2007	71.777	8458.276384
# Africa	Uganda	5824797	1952	39.978	734.753484
# Africa	Uganda	6675501	1957	42.571	774.3710692
# Africa	Uganda	7688797	1962	45.344	767.2717398
# Africa	Uganda	8900294	1967	48.051	908.9185217
# Africa	Uganda	10190285	1972	51.016	950.735869
# Africa	Uganda	11457758	1977	50.35	843.7331372
# Africa	Uganda	12939400	1982	49.849	682.2662268
# Africa	Uganda	15283050	1987	51.509	617.7244065
# Africa	Uganda	18252190	1992	48.825	644.1707969
# Africa	Uganda	21210254	1997	44.578	816.559081
# Africa	Uganda	24739869	2002	47.813	927.7210018
# Africa	Uganda	29170398	2007	51.542	1056.380121
# Europe	United Kingdom	50430000	1952	69.18	9979.508487
# Europe	United Kingdom	51430000	1957	70.42	11283.17795
# Europe	United Kingdom	53292000	1962	70.76	12477.17707
# Europe	United Kingdom	54959000	1967	71.36	14142.85089
# Europe	United Kingdom	56079000	1972	72.01	15895.11641
# Europe	United Kingdom	56179000	1977	72.76	17428.74846
# Europe	United Kingdom	56339704	1982	74.04	18232.42452
# Europe	United Kingdom	56981620	1987	75.007	21664.78767
# Europe	United Kingdom	57866349	1992	76.42	22705.09254
# Europe	United Kingdom	58808266	1997	77.218	26074.53136
# Europe	United Kingdom	59912431	2002	78.471	29478.99919
# Europe	United Kingdom	60776238	2007	79.425	33203.26128
# Americas	United States	157553000	1952	68.44	13990.48208
# Americas	United States	171984000	1957	69.49	14847.12712
# Americas	United States	186538000	1962	70.21	16173.14586
# Americas	United States	198712000	1967	70.76	19530.36557
# Americas	United States	209896000	1972	71.34	21806.03594
# Americas	United States	220239000	1977	73.38	24072.63213
# Americas	United States	232187835	1982	74.65	25009.55914
# Americas	United States	242803533	1987	75.02	29884.35041
# Americas	United States	256894189	1992	76.09	32003.93224
# Americas	United States	272911760	1997	76.81	35767.43303
# Americas	United States	287675526	2002	77.31	39097.09955
# Americas	United States	301139947	2007	78.242	42951.65309
# Americas	Uruguay	2252965	1952	66.071	5716.766744
# Americas	Uruguay	2424959	1957	67.044	6150.772969
# Americas	Uruguay	2598466	1962	68.253	5603.357717
# Americas	Uruguay	2748579	1967	68.468	5444.61962
# Americas	Uruguay	2829526	1972	68.673	5703.408898
# Americas	Uruguay	2873520	1977	69.481	6504.339663
# Americas	Uruguay	2953997	1982	70.805	6920.223051
# Americas	Uruguay	3045153	1987	71.918	7452.398969
# Americas	Uruguay	3149262	1992	72.752	8137.004775
# Americas	Uruguay	3262838	1997	74.223	9230.240708
# Americas	Uruguay	3363085	2002	75.307	7727.002004
# Americas	Uruguay	3447496	2007	76.384	10611.46299
# Americas	Venezuela	5439568	1952	55.088	7689.799761
# Americas	Venezuela	6702668	1957	57.907	9802.466526
# Americas	Venezuela	8143375	1962	60.77	8422.974165
# Americas	Venezuela	9709552	1967	63.479	9541.474188
# Americas	Venezuela	11515649	1972	65.712	10505.25966
# Americas	Venezuela	13503563	1977	67.456	13143.95095
# Americas	Venezuela	15620766	1982	68.557	11152.41011
# Americas	Venezuela	17910182	1987	70.19	9883.584648
# Americas	Venezuela	20265563	1992	71.15	10733.92631
# Americas	Venezuela	22374398	1997	72.146	10165.49518
# Americas	Venezuela	24287670	2002	72.766	8605.047831
# Americas	Venezuela	26084662	2007	73.747	11415.80569
# Asia	Vietnam	26246839	1952	40.412	605.0664917
# Asia	Vietnam	28998543	1957	42.887	676.2854478
# Asia	Vietnam	33796140	1962	45.363	772.0491602
# Asia	Vietnam	39463910	1967	47.838	637.1232887
# Asia	Vietnam	44655014	1972	50.254	699.5016441
# Asia	Vietnam	50533506	1977	55.764	713.5371196
# Asia	Vietnam	56142181	1982	58.816	707.2357863
# Asia	Vietnam	62826491	1987	62.82	820.7994449
# Asia	Vietnam	69940728	1992	67.662	989.0231487
# Asia	Vietnam	76048996	1997	70.672	1385.896769
# Asia	Vietnam	80908147	2002	73.017	1764.456677
# Asia	Vietnam	85262356	2007	74.249	2441.576404
# Asia	West Bank and Gaza	1030585	1952	43.16	1515.592329
# Asia	West Bank and Gaza	1070439	1957	45.671	1827.067742
# Asia	West Bank and Gaza	1133134	1962	48.127	2198.956312
# Asia	West Bank and Gaza	1142636	1967	51.631	2649.715007
# Asia	West Bank and Gaza	1089572	1972	56.532	3133.409277
# Asia	West Bank and Gaza	1261091	1977	60.765	3682.831494
# Asia	West Bank and Gaza	1425876	1982	64.406	4336.032082
# Asia	West Bank and Gaza	1691210	1987	67.046	5107.197384
# Asia	West Bank and Gaza	2104779	1992	69.718	6017.654756
# Asia	West Bank and Gaza	2826046	1997	71.096	7110.667619
# Asia	West Bank and Gaza	3389578	2002	72.37	4515.487575
# Asia	West Bank and Gaza	4018332	2007	73.422	3025.349798
# Asia	Yemen Rep	4963829	1952	32.548	781.7175761
# Asia	Yemen Rep	5498090	1957	33.97	804.8304547
# Asia	Yemen Rep	6120081	1962	35.18	825.6232006
# Asia	Yemen Rep	6740785	1967	36.984	862.4421463
# Asia	Yemen Rep	7407075	1972	39.848	1265.047031
# Asia	Yemen Rep	8403990	1977	44.175	1829.765177
# Asia	Yemen Rep	9657618	1982	49.113	1977.55701
# Asia	Yemen Rep	11219340	1987	52.922	1971.741538
# Asia	Yemen Rep	13367997	1992	55.599	1879.496673
# Asia	Yemen Rep	15826497	1997	58.02	2117.484526
# Asia	Yemen Rep	18701257	2002	60.308	2234.820827
# Asia	Yemen Rep	22211743	2007	62.698	2280.769906
# Africa	Zambia	2672000	1952	42.038	1147.388831
# Africa	Zambia	3016000	1957	44.077	1311.956766
# Africa	Zambia	3421000	1962	46.023	1452.725766
# Africa	Zambia	3900000	1967	47.768	1777.077318
# Africa	Zambia	4506497	1972	50.107	1773.498265
# Africa	Zambia	5216550	1977	51.386	1588.688299
# Africa	Zambia	6100407	1982	51.821	1408.678565
# Africa	Zambia	7272406	1987	50.821	1213.315116
# Africa	Zambia	8381163	1992	46.1	1210.884633
# Africa	Zambia	9417789	1997	40.238	1071.353818
# Africa	Zambia	10595811	2002	39.193	1071.613938
# Africa	Zambia	11746035	2007	42.384	1271.211593
# Africa	Zimbabwe	3080907	1952	48.451	406.8841148
# Africa	Zimbabwe	3646340	1957	50.469	518.7642681
# Africa	Zimbabwe	4277736	1962	52.358	527.2721818
# Africa	Zimbabwe	4995432	1967	53.995	569.7950712
# Africa	Zimbabwe	5861135	1972	55.635	799.3621758
# Africa	Zimbabwe	6642107	1977	57.674	685.5876821
# Africa	Zimbabwe	7636524	1982	60.363	788.8550411
# Africa	Zimbabwe	9216418	1987	62.351	706.1573059
# Africa	Zimbabwe	10704340	1992	60.377	693.4207856
# Africa	Zimbabwe	11404948	1997	46.809	792.4499603
# Africa	Zimbabwe	11926563	2002	39.989	672.0386227
# Africa	Zimbabwe	12311143	2007	43.487	469.7092981

# %% [markdown]
# ## Getting help from the official Python documentation
#
# The most useful information is online on https://www.python.org/ website and should  be used as a reference guide.
#
# - [Python3 documentation](https://docs.python.org/3/) is the starting page with links to tutorials and libraries' documentation for Python 3
#     - [The Python Tutorial](https://docs.python.org/3/tutorial/index.html)
#         - [Modules](https://docs.python.org/3/tutorial/modules.html)
#         - [Brief Tour of the Standard Library: Mathematics](https://docs.python.org/3/tutorial/stdlib.html#mathematics)
#     - [The Python Standard Library Reference](https://docs.python.org/3/library/index.html) is the reference documentation of all libraries included in Python like:
#         - [`statistics` - Mathematical statistics functions](https://docs.python.org/3/library/statistics.html)
#         - [`os.path` — Common pathname manipulations](https://docs.python.org/3/library/os.path.html)
#         - [`os` — Miscellaneous operating system interfaces](https://docs.python.org/3/library/os.html)
#         - [`csv` — CSV File Reading and Writing](https://docs.python.org/3/library/csv.html)

# %% [markdown]
# ## Exercise 1.2.3
#
# - Change the script you wrote for [Exercise 1.2.1](#Exercise-1.2.1) to make use of the `csv` module to calculate the average GDP per capita per country in Europe in 1962, its median and standard deviation using `data/gapminder.csv` data; and compare these figures with those from Americas.

# %%
import csv
from statistics import mean, stdev

fName = os.path.join("data","gapminder.csv")
#check if exists
if os.path.exists(fName):
    print('{} is present'.format(fName))
    
gdp_1962_EU = []   

with open(fName, 'r') as f:
#with open("data/gapminder.csv") as f:
    reader = csv.DictReader(f, delimiter = ',')
    for data in reader:
        if data['continent'] == 'Europe' and data['year'] == '1962':
            gdp_1962_EU.append(float(data['gdpPercap']))


print('EU GDP per cap in 1962, mean {:.2f}, std {:.2f}'.format(mean(gdp_1962_EU),stdev(gdp_1962_EU)))
# Out:
# data/gapminder.csv is present
# EU GDP per cap in 1962, mean 8365.49, std 4199.19

# %% [markdown]
# ## Next session
#
# Go to our next notebook: [Session 1.3: Creating functions and modules to write reusable code](13_python_data.ipynb)
